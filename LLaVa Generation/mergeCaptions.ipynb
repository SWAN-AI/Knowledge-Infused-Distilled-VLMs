# %%
import json

# %%
file1 = open('./newCaptions_no_target_0_6000.json')
file2 = open('./newCaptions_no_target_6000_13000.json')

data1 = json.load(file1)
data2 = json.load(file2)

# %%
data1.update(data2)

print(len(data1)) 
with open('./newCaptionsLLAVA_no_target.json', 'w') as f:
    json.dump(data1, f, indent=4)
# Out:
# 12140
