# %%
import os
import json
from tqdm import tqdm
from pathlib import Path
from icecream import ic
from collections import OrderedDict
import sys
import pickle as pkl
import matplotlib.pyplot as plt
import networkx as nx
import copy

# %%
# !ls /scratch/rahul.garg/*h1*
# Out:
# /scratch/rahul.garg/allCmgs_newTarget_h1_RelevancyKCMGS_6000_12500.jsonl
# /scratch/rahul.garg/allCmgs_newTarget_h1_RelevancyKCMGS.jsonl

# %%
jsonlFile = '/scratch/rahul.garg/allCmgs_noTargetFixed_h1_RelevancyKCMGS.jsonl'
jsonFile = open(jsonlFile, 'r')
allLines = jsonFile.readlines()
jsonFile.close()

# %%
for i in tqdm(range(len(allLines))):
    allLines[i] = json.loads(allLines[i])
# Out:
# 100%|██████████| 12126/12126 [09:59<00:00, 20.24it/s]

# %%
k = 750

# %%
lengths = []
edgeLengths = []
for obj in tqdm(allLines):
    graph = obj['graph']

    nodes = graph['nodeDataArray']
    # print(len(nodes))
    # break
    nodesSet = set()
    # print("________________")
    for node in nodes:
        if node['key'] in nodesSet:
            print(node)
        nodesSet.add(node['key'])
    lengths.append(len(nodesSet))
    # print("________________")
    # verify edge duplicatio
    edges = graph['linkDataArray']
    edgesSet = set()
    for edge in edges:
        tup = (edge['from'], edge['to'])
        if tup in edgesSet:
            print(edge)
        edgesSet.add(tup)

    edgeLengths.append(len(edgesSet))

    

plt.hist(lengths, bins=100)
# make a line at 200
plt.axvline(x=k, color='r', linestyle='--')
plt.show()

plt.hist(edgeLengths, bins=100)
plt.show()
# Out:
#   0%|          | 0/12126 [00:00<?, ?it/s]
# 100%|██████████| 12126/12126 [01:58<00:00, 102.28it/s]

# %%
# sum of lengths
sum(lengths) / len(lengths)
# Out:
# 2541.5

# %%
sum(edgeLengths) / len(edgeLengths)
# Out:
# 19356.451426686457

# %%
scores = []

for obj in tqdm(allLines):
    graph = obj['graph']

    nodes = graph['nodeDataArray']

    for node in nodes:
        score = node['score']
        scores.append(score)

plt.hist(scores, bins=100)
plt.show()
# Out:
# 100%|██████████| 12126/12126 [00:05<00:00, 2405.49it/s]

# %%
sum(scores) / len(scores)
# Out:
# -16.838081048594223

# %%
# RelScores = {}
# for obj in tqdm(allLines):
#     graph = obj['graph']
#     nodes = graph['nodeDataArray']
#     if obj['id'] not in RelScores:
#         RelScores[obj['id']] = {}

#     for node in nodes:
#         if node['key'] not in RelScores[obj['id']]:
#             RelScores[obj['id']][node['key']] = node['score']
#         elif abs(RelScores[obj['id']][node['key']] - node['score']) > 1e-3:
#             print("Duplicate key")
#             print(node)
#             print(obj['id'])
#             print(RelScores[obj['id']][node['key']])

# RelScores

# %%
# newFile = '/scratch/rahul.garg/conceptNet/allCmgs_fullContextFixed_h1.jsonl'
# # add these scores to its nodes
# jsonFile = open(newFile, 'r')
# allLines2 = jsonFile.readlines()
# jsonFile.close()

# for i in tqdm(range(len(allLines2))):
#     allLines2[i] = json.loads(allLines2[i])

# %%
# allLines2[0]

# %%
# for obj in tqdm(allLines2):
#     graph = obj['graph']
#     nodes = graph['nodeDataArray']
#     for node in nodes:
#         node['score'] = RelScores[obj['id']][node['key']]

# # newFile = '/scratch/rahul.garg/conceptNet/allCmgs_fullContextFixed_h1_withScores.jsonl'
# # jsonFile = open(newFile, 'w')
# # for obj in tqdm(allLines2):
# #     json.dump(obj, jsonFile)
# #     jsonFile.write('\n')

# %%
id2Concepts = {}

with open('../entityExtractionQagnn/ground_res_without_target.jsonl', 'r') as f:
    allCompulsoryNodes = f.readlines()
    for i in range(len(allCompulsoryNodes)):
        obj = json.loads(allCompulsoryNodes[i])
        id2Concepts[obj['id']] = obj['res']['qc']

id2Concepts
# Out:
# {37295: ['baby',
#   'baby_girl',
#   'black',
#   'box',
#   'camera',
#   'cute',
#   'get',
#   'gift',
#   'girl',
#   'guy',
#   'red',
#   'see',
#   'sit',
#   'sitting',
#   'smile',
#   'smiling',
#   'white'],
#  6287: ['contest',
#   'court',
#   'gold',
#   'gold_medal',
#   'group',
#   'medal',
#   'outdoor',
#   'people',
#   'play',
#   'playing',
#   'playing_table_tennis',
#   'spectator',
#   'spectators',
#   'surround',
#   'surrounded',
#   'table',
#   'table_tennis',
#   'tennis',
#   'walk',
#   'walking',
#   'well',
#   'wheelchair',
#   'win',
#   'winning'],
#  42690: ['black',
#   'gas',
#   'glass',
#   'juice',
#   'man',
#   'mustache',
#   'ol',
#   'old',
#   'photograph',
#   'photographed',
#   'sad',
#   'tie',
#   'white'],
#  39625: ['aerial',
#   'aerial_view',
#   'city',
#   'city_skyline',
#   'forget',
#   'forgot',
#   'government',
#   'include',
#   'including',
#   'never',
#   'never_forget',
#   'new',
#   'new_york',
#   'new_york_city',
#   'said',
#   'say',
#   'skyline',
#   'tower',
#   'towers',
#   'twin',
#   'twin_towers',
#   'view',
#   'vote',
#   'york'],
#  18542: ['day',
#   'depict',
#   'depicting',
#   'engraving',
#   'field',
#   'flower',
#   'flowers',
#   'group',
#   'king',
#   'luther',
#   'martin',
#   'martin_luther',
#   'martin_luther_king',
#   'martin_luther_king_day',
#   'people',
#   'people_working',
#   'work',
#   'working'],
#  20491: ['clap',
#   'front',
#   'hand',
#   'hands',
#   'happy',
#   'house',
#   'indonesian',
#   'know',
#   'stand',
#   'stands',
#   'traditional',
#   'woman',
#   'wooden'],
#  21740: ['christmas_tree',
#   'front',
#   'hooker',
#   'hookers',
#   'keep',
#   'keeping',
#   'laid',
#   'lay',
#   'navy',
#   'pose',
#   'posing',
#   'sailor',
#   'since',
#   'tranny',
#   'tree',
#   'treed'],
#  79581: ['attack',
#   'big',
#   'big_bird',
#   'bird',
#   'birds',
#   'character',
#   'child',
#   'children',
#   'childrens',
#   'famous',
#   'front',
#   'group',
#   'large',
#   'like',
#   'mascot',
#   'mostly',
#   'prey',
#   'resemble',
#   'resembles',
#   'scavenger',
#   'scavengers',
#   'sesame',
#   'sesame_street',
#   'show',
#   'specie',
#   'species',
#   'stand',
#   'standing',
#   'street',
#   'television',
#   'television_show',
#   'turkey',
#   'turkey_vulture',
#   'vulture',
#   'weaken',
#   'weakened',
#   'yellow',
#   'yellow_bird'],
#  76108: ['appear',
#   'appears',
#   'attention',
#   'cloud',
#   'clouded',
#   'create',
#   'creates',
#   'dishwasher',
#   'dishwashers',
#   'eyecatching',
#   'finger',
#   'fingers',
#   'formation',
#   'gaze',
#   'god',
#   'hand',
#   'human',
#   'human_hand',
#   'humans',
#   'image',
#   'like',
#   'look',
#   'look_like',
#   'person',
#   'persons',
#   'persons_hand',
#   'resemble',
#   'resembles',
#   'show',
#   'shows',
#   'sight',
#   'sky',
#   'thumb',
#   'unique',
#   'viewer',
#   'viewers',
#   'woman',
#   'women'],
#  63057: ['arm',
#   'bandage',
#   'bandaged',
#   'bed',
#   'beds',
#   'day',
#   'days',
#   'girl',
#   'girls',
#   'hospital',
#   'hospital_bed',
#   'kid',
#   'kids',
#   'lay',
#   'leg',
#   'lie',
#   'much',
#   'rely',
#   'technology',
#   'two',
#   'twos',
#   'young',
#   'young_girl',
#   'young_girls'],
#  96415: ['arse',
#   'beard',
#   'bearded',
#   'fuck',
#   'glass',
#   'glasses',
#   'goat',
#   'hat',
#   'man',
#   'mohammed',
#   'name',
#   'praise',
#   'prophet',
#   'red',
#   'red_hat',
#   'wear',
#   'wear_glasses',
#   'wearing'],
#  38496: ['attention',
#   'background',
#   'black',
#   'camera',
#   'capture',
#   'capturing',
#   'closeup',
#   'contrast',
#   'create',
#   'creating',
#   'dark',
#   'darkness',
#   'directly',
#   'dramatic',
#   'expression',
#   'face',
#   'facial',
#   'facial_expression',
#   'feature',
#   'features',
#   'front',
#   'image',
#   'intense',
#   'man',
#   'open',
#   'romanian',
#   'romanians',
#   'see',
#   'shirt',
#   'shot',
#   'slightly',
#   'smile',
#   'smiling',
#   'stand',
#   'standing',
#   'stare',
#   'stares',
#   'surround',
#   'surrounding',
#   'viewer',
#   'viewers',
#   'wear',
#   'wearing',
#   'young',
#   'young_man'],
#  21746: ['background',
#   'barely',
#   'know',
#   'large',
#   'much',
#   'paper',
#   'picture',
#   'pile',
#   'shredded_paper',
#   'start',
#   'trash',
#   'white',
#   'white_trash'],
#  37862: ['add',
#   'adding',
#   'appear',
#   'background',
#   'bench',
#   'communication',
#   'company',
#   'enjoy',
#   'enjoying',
#   'entertainment',
#   'fucking',
#   'hold',
#   'holding',
#   'laugh',
#   'laughing',
#   'man',
#   'must',
#   'natural',
#   'outdoor',
#   'park',
#   'park_bench',
#   'relax',
#   'relaxing',
#   'retard',
#   'retarded',
#   'scene',
#   'sit',
#   'sitting',
#   'smile',
#   'smiling',
#   'tablet',
#   'think',
#   'time',
#   'together',
#   'touch',
#   'tree',
#   'treed',
#   'use',
#   'using',
#   'visible',
#   'woman'],
#  35970: ['add',
#   'adding',
#   'appear',
#   'appears',
#   'background',
#   'boy',
#   'boys',
#   'camera',
#   'chin',
#   'close',
#   'focal',
#   'focal_point',
#   'gray',
#   'ground',
#   'grow',
#   'grown',
#   'hand',
#   'hands',
#   'head',
#   'image',
#   'lol',
#   'natural',
#   'nevermind',
#   'photo',
#   'point',
#   'pose',
#   'posing',
#   'position',
#   'positioned',
#   'rest',
#   'resting',
#   'scene',
#   'several',
#   'shirt',
#   'sit',
#   'sitting',
#   'touch',
#   'tree',
#   'treed',
#   'trees',
#   'visible',
#   'wear',
#   'wearing',
#   'young',
#   'young_boy'],
#  32768: ['also',
#   'appear',
#   'appears',
#   'armrest',
#   'armrests',
#   'content',
#   'desk',
#   'deskest',
#   'display',
#   'displaying',
#   'displaying_information',
#   'engross',
#   'engrossed',
#   'everything',
#   'glass',
#   'glasses',
#   'hand',
#   'hands',
#   'head',
#   'image',
#   'imdb',
#   'information',
#   'laptop',
#   'man',
#   'man_working',
#   'mans',
#   'monitor',
#   'next',
#   'place',
#   'placed',
#   'relate',
#   'related',
#   'rest',
#   'resting',
#   'sit',
#   'sitting',
#   'slightly',
#   'theory',
#   'tilt',
#   'tilted',
#   'towards',
#   'wear',
#   'wear_glasses',
#   'wearing',
#   'wheelchair',
#   'work'],
#  69357: ['add',
#   'adding',
#   'addition',
#   'appear',
#   'appears',
#   'atmosphere',
#   'background',
#   'create',
#   'creating',
#   'enjoy',
#   'enjoying',
#   'event',
#   'feature',
#   'features',
#   'festival',
#   'glass',
#   'glasses',
#   'good',
#   'good_time',
#   'hat',
#   'hey',
#   'image',
#   'laugh',
#   'laughing',
#   'lively',
#   'look',
#   'man',
#   'ol',
#   'old',
#   'old_man',
#   'people',
#   'scene',
#   'serial',
#   'several',
#   'smile',
#   'smiling',
#   'surround',
#   'surrounded',
#   'surrounding',
#   'surroundings',
#   'time',
#   'vibrant',
#   'visible',
#   'wear',
#   'wearing',
#   'yellow'],
#  1423: ['appear',
#   'atmosphere',
#   'back',
#   'bed',
#   'company',
#   'cover',
#   'covered',
#   'cuddle',
#   'cuddling',
#   'day',
#   'enjoy',
#   'enjoying',
#   'head',
#   'image',
#   'intimate',
#   'lay',
#   'lie',
#   'long',
#   'long_day',
#   'lying',
#   'man',
#   'men',
#   'mud',
#   'mudding',
#   'muds',
#   'naked',
#   'naked_men',
#   'nap',
#   'near',
#   'one_man',
#   'overall',
#   'pillow',
#   'scene',
#   'sensual',
#   'sheet',
#   'sheets',
#   'stomach',
#   'together',
#   'two',
#   'twos',
#   'white',
#   'white_sheet',
#   'white_sheets'],
#  57986: ['add',
#   'adds',
#   'appear',
#   'appears',
#   'aspect',
#   'background',
#   'behind',
#   'behindest',
#   'car',
#   'car_park',
#   'commute',
#   'commuting',
#   'cultural',
#   'drive',
#   'driving',
#   'enjoy',
#   'enjoying',
#   'errand',
#   'errands',
#   'hijab',
#   'hold',
#   'holding',
#   'love',
#   'lovin',
#   'park',
#   'parked',
#   'religious',
#   'road',
#   'run',
#   'run_errand',
#   'running',
#   'running_errands',
#   'scene',
#   'side',
#   'smile',
#   'smiling',
#   'steering',
#   'time',
#   'wear',
#   'wearing',
#   'wheel',
#   'white',
#   'woman',
#   'woman_wear',
#   'work'],
#  5728: ['big',
#   'big_city',
#   'city',
#   'engulf',
#   'engulfed',
#   'fall',
#   'falling',
#   'flame',
#   'flames',
#   'new',
#   'new_york',
#   'new_york_city',
#   'september',
#   'skyscraper',
#   'skyscrapers',
#   'smoke',
#   'tower',
#   'towers',
#   'twin',
#   'twin_towers',
#   'york'],
#  57386: ['add',
#   'adding',
#   'appear',
#   'appears',
#   'arm',
#   'arms',
#   'atmosphere',
#   'background',
#   'beach',
#   'body',
#   'close',
#   'closed',
#   'enjoy',
#   'enjoying',
#   'eye',
#   'eye_closed',
#   'eyes',
#   'eyes_closed',
#   'free',
#   'free_stuff',
#   'give',
#   'lake',
#   'meditate',
#   'meditating',
#   'mountain',
#   'mountains',
#   'natural',
#   'near',
#   'outstretched',
#   'peaceful',
#   'scene',
#   'serene',
#   'stand',
#   'standing',
#   'state',
#   'stuff',
#   'surrounding',
#   'surroundings',
#   'tit',
#   'tits',
#   'visible',
#   'water',
#   'woman'],
#  48710: ['appear',
#   'appears',
#   'area',
#   'chevy',
#   'drive',
#   'driving',
#   'escape',
#   'feature',
#   'features',
#   'first',
#   'first_one',
#   'ford',
#   'get',
#   'get_stick',
#   'getting',
#   'go',
#   'guy',
#   'guys',
#   'highlight',
#   'highlighting',
#   'image',
#   'images',
#   'mud',
#   'muddy',
#   'muds',
#   'navigate',
#   'navigated',
#   'photo',
#   'photos',
#   'second',
#   'second_one',
#   'showcase',
#   'showcasing',
#   'stick',
#   'stuck',
#   'successful',
#   'successfully',
#   'terrain',
#   'truck',
#   'truck_driving',
#   'trucks',
#   'two',
#   'twos',
#   'visible',
#   'way'],
#  98305: ['bring',
#   'bringing',
#   'come',
#   'coming',
#   'handcuff',
#   'handcuffs',
#   'president'],
#  1954: ['add',
#   'adding',
#   'additionally',
#   'area',
#   'around',
#   'atmosphere',
#   'attention',
#   'background',
#   'best',
#   'black',
#   'boot',
#   'boots',
#   'capture',
#   'captures',
#   'car',
#   'cars',
#   'create',
#   'die',
#   'dress',
#   'dying',
#   'eyecatching',
#   'fence',
#   'free',
#   'get',
#   'good',
#   'good_part',
#   'hour',
#   'illuminate',
#   'illuminated',
#   'illuminating',
#   'image',
#   'lean',
#   'leaning',
#   'left',
#   'leg',
#   'metal',
#   'night',
#   'outfit',
#   'part',
#   'pose',
#   'posing',
#   'prostitute',
#   'protrude',
#   'protruding',
#   'red',
#   'scene',
#   'second',
#   'second_hour',
#   'set',
#   'several',
#   'side',
#   'streetlight',
#   'streetlights',
#   'urban',
#   'viewer',
#   'visible',
#   'wall',
#   'woman'],
#  46813: ['catch',
#   'first',
#   'first_time',
#   'goat',
#   'hind',
#   'hind_leg',
#   'hind_legs',
#   'hold',
#   'holding',
#   'leg',
#   'legs',
#   'man',
#   'picture',
#   'pictures',
#   'sex',
#   'stand',
#   'standing',
#   'teenage',
#   'time',
#   'times_two',
#   'two',
#   'twos'],
#  8137: ['allow',
#   'allowing',
#   'appear',
#   'appears',
#   'around',
#   'back',
#   'back_leg',
#   'back_legs',
#   'bottom',
#   'bottomed',
#   'bowl',
#   'cannibalism',
#   'center',
#   'closeup',
#   'environment',
#   'extend',
#   'extended',
#   'focus',
#   'focused',
#   'frame',
#   'front',
#   'front_leg',
#   'glass',
#   'habitat',
#   'image',
#   'interact',
#   'leg',
#   'legs',
#   'mantis',
#   'move',
#   'move_around',
#   'natural',
#   'natural_habitat',
#   'observe',
#   'observing',
#   'outside',
#   'position',
#   'positioned',
#   'pray',
#   'praying',
#   'praying_mantis',
#   'prey',
#   'rest',
#   'resting',
#   'rim',
#   'search',
#   'searching',
#   'serve',
#   'serves',
#   'sit',
#   'sitting',
#   'surrounding',
#   'surroundings',
#   'top',
#   'towards',
#   'view'],
#  97063: ['add',
#   'adds',
#   'adjust',
#   'adjusting',
#   'appear',
#   'appearance',
#   'appears',
#   'around',
#   'bandage',
#   'bomb',
#   'bomb_explodes',
#   'bombs_exploding',
#   'crowd',
#   'dress',
#   'dressed',
#   'event',
#   'explode',
#   'exploded',
#   'feature',
#   'features',
#   'head',
#   'image',
#   'important',
#   'important_event',
#   'man',
#   'necktie',
#   'photo',
#   'photo_shoot',
#   'prepare',
#   'preparing',
#   'shoot',
#   'shot',
#   'stand',
#   'suit',
#   'tie',
#   'touch',
#   'unique',
#   'unusual',
#   'wrap',
#   'wrap_around',
#   'wrapped'],
#  95162: ['appear',
#   'appears',
#   'associate',
#   'associated',
#   'atmosphere',
#   'bonfire',
#   'celebration',
#   'come',
#   'coming',
#   'create',
#   'creating',
#   'cross',
#   'dramatic',
#   'event',
#   'field',
#   'flame',
#   'flames',
#   'group',
#   'hold',
#   'holding',
#   'hug',
#   'intense',
#   'large',
#   'man',
#   'middle',
#   'nazi',
#   'nobody',
#   'part',
#   'people',
#   'religious',
#   'ritual',
#   'scene',
#   'spiritual',
#   'stand',
#   'standing',
#   'surround',
#   'surrounded',
#   'wooden'],
#  42691: ['age',
#   'aged',
#   'ages',
#   'american',
#   'american_flag',
#   'americans',
#   'belief',
#   'beliefs',
#   'confederate',
#   'confederate_flag',
#   'crowd',
#   'demonstration',
#   'different',
#   'diverse',
#   'donald',
#   'ethnicities',
#   'ethnicity',
#   'event',
#   'express',
#   'flag',
#   'flags',
#   'gather',
#   'gathered',
#   'gender',
#   'genderest',
#   'genders',
#   'group',
#   'hold',
#   'holding',
#   'include',
#   'including',
#   'man',
#   'opinion',
#   'opinions',
#   'outdoor',
#   'outdoor_event',
#   'participate',
#   'people',
#   'protest',
#   'red',
#   'shirt',
#   'sir',
#   'stand',
#   'stand_together',
#   'standing',
#   'standing_together',
#   'together',
#   'trump',
#   'various',
#   'vote',
#   'voted',
#   'yes'],
#  40239: ['additionally',
#   'adjust',
#   'adjusting',
#   'announcement',
#   'another',
#   'another_man',
#   'background',
#   'collusion',
#   'counter',
#   'donald',
#   'front',
#   'give',
#   'image',
#   'include',
#   'including',
#   'left',
#   'man',
#   'man_sitting',
#   'microphone',
#   'myth',
#   'people',
#   'prepare',
#   'preparing',
#   'present',
#   'president',
#   'punch',
#   'ready',
#   'right',
#   'right_side',
#   'room',
#   'russia',
#   'russias',
#   'scene',
#   'several',
#   'side',
#   'sit',
#   'sitting',
#   'speech',
#   'stand',
#   'standing',
#   'suit',
#   'tie',
#   'trump',
#   'two',
#   'two_women',
#   'twos',
#   'visible',
#   'wear',
#   'wearing',
#   'woman',
#   'women',
#   'wristwatch'],
#  12784: ['accompanied',
#   'accompany',
#   'add',
#   'add_flavor',
#   'adding',
#   'adding_flavor',
#   'board',
#   'chinese',
#   'chinese_food',
#   'combination',
#   'completely',
#   'cut',
#   'cut_boards',
#   'cutting',
#   'cutting_board',
#   'delicious',
#   'dish',
#   'dished',
#   'flavor',
#   'food',
#   'healthy',
#   'herb',
#   'herbs',
#   'ingredient',
#   'ingredients',
#   'lemon',
#   'lemons',
#   'meal',
#   'oil',
#   'olive',
#   'olive_oil',
#   'option',
#   'pepper',
#   'piece',
#   'place',
#   'placed',
#   'salmon',
#   'salt',
#   'season',
#   'seasoned',
#   'show',
#   'shows',
#   'various',
#   'wooden'],
#  29013: ['camel',
#   'camels',
#   'closeup',
#   'club',
#   'expression',
#   'feature',
#   'features',
#   'first',
#   'front',
#   'funny',
#   'funny_expression',
#   'herd',
#   'image',
#   'isis',
#   'man',
#   'meanwhile',
#   'men',
#   'mouth',
#   'mouth_open',
#   'next',
#   'open',
#   'photograph',
#   'photographed',
#   'photographs',
#   'pose',
#   'posing',
#   'right',
#   'right_side',
#   'second',
#   'see',
#   'seen',
#   'show',
#   'shows',
#   'side',
#   'stand',
#   'standing',
#   'strip',
#   'strip_club',
#   'third',
#   'third_man',
#   'three',
#   'turban',
#   'turbans',
#   'two',
#   'twos',
#   'view',
#   'wear',
#   'wearing',
#   'white',
#   'wide',
#   'wide_open'],
#  84750: ['allow',
#   'allowing',
#   'around',
#   'background',
#   'camera',
#   'capture',
#   'captures',
#   'contact',
#   'curly',
#   'curly_hair',
#   'directly',
#   'door',
#   'enter',
#   'essence',
#   'eye',
#   'eye_contact',
#   'gas',
#   'hair',
#   'image',
#   'light',
#   'look',
#   'looking',
#   'make_eye_contact',
#   'make_eyes',
#   'natural',
#   'natural_light',
#   'neck',
#   'open',
#   'open_door',
#   'overall',
#   'personality',
#   'room',
#   'scarf',
#   'sec',
#   'stand',
#   'standing',
#   'style',
#   'sweater',
#   'try',
#   'trying',
#   'u',
#   'viewer',
#   'wait',
#   'wear',
#   'wearing',
#   'window',
#   'woman'],
#  85329: ['actively',
#   'around',
#   'atmosphere',
#   'belief',
#   'beliefs',
#   'black',
#   'black_man',
#   'burn',
#   'burning',
#   'capture',
#   'captures',
#   'cast',
#   'casting',
#   'create',
#   'creating',
#   'cross',
#   'dramatic',
#   'dress',
#   'dressed',
#   'eerie',
#   'field',
#   'flame',
#   'flames',
#   'gather',
#   'gather_around',
#   'gathered',
#   'genocide',
#   'glow',
#   'group',
#   'hate',
#   'hood',
#   'image',
#   'intimidate',
#   'intimidating',
#   'intolerance',
#   'klan',
#   'ku_klux_klan',
#   'light',
#   'lit',
#   'man',
#   'member',
#   'members',
#   'men',
#   'message',
#   'middle',
#   'moment',
#   'ominous',
#   'photograph',
#   'photographed',
#   'practice',
#   'practicing',
#   'robe',
#   'robes',
#   'scene',
#   'spread',
#   'spreading',
#   'support',
#   'supporting',
#   'time',
#   'white'],
#  32091: ['appear',
#   'appears',
#   'area',
#   'arrow',
#   'arrows',
#   'confidently',
#   'direction',
#   'environment',
#   'focus',
#   'focused',
#   'guide',
#   'guiding',
#   'hold',
#   'holding',
#   'large',
#   'large_white',
#   'life',
#   'live',
#   'man',
#   'middle',
#   'point',
#   'pointing',
#   'position',
#   'positioned',
#   'sandy',
#   'sandy_area',
#   'specific',
#   'specific_directions',
#   'stand',
#   'standing',
#   'towards',
#   'two',
#   'twos',
#   'upward',
#   'way',
#   'wear',
#   'wearing',
#   'white'],
#  82097: ['add',
#   'additionally',
#   'appearance',
#   'attention',
#   'background',
#   'beautiful',
#   'capture',
#   'captures',
#   'cell',
#   'cell_phone',
#   'corner',
#   'cornered',
#   'diet',
#   'door',
#   'element',
#   'elements',
#   'focal',
#   'focal_point',
#   'free',
#   'front',
#   'fuck',
#   'gluten',
#   'gluten_free',
#   'handbag',
#   'image',
#   'include',
#   'including',
#   'left',
#   'low',
#   'near',
#   'pair',
#   'phone',
#   'photo',
#   'place',
#   'placed',
#   'point',
#   'pose',
#   'posing',
#   'present',
#   'right',
#   'right_side',
#   'scene',
#   'several',
#   'shirt',
#   'shut',
#   'shutting',
#   'side',
#   'stand',
#   'standing',
#   'strike',
#   'striking',
#   'sunglass',
#   'sunglasses',
#   'vegan',
#   'viewer',
#   'visible',
#   'wall',
#   'wear',
#   'wearing',
#   'white',
#   'woman',
#   'womans'],
#  84752: ['living_room',
#   'meditate',
#   'meditating',
#   'pregnant',
#   'pregnant_woman',
#   'room',
#   'woman'],
#  98307: ['ashe',
#   'ashes',
#   'auschwitz',
#   'broom',
#   'chick',
#   'chicks',
#   'fireplace',
#   'man',
#   'pick',
#   'sweep',
#   'use',
#   'using'],
#  8732: ['also',
#   'bed',
#   'child',
#   'company',
#   'depict',
#   'depicts',
#   'dog',
#   'enjoy',
#   'enjoying',
#   'envision',
#   'family',
#   'first',
#   'guy',
#   'guys',
#   'image',
#   'laptop',
#   'lesbian',
#   'lesbians',
#   'like',
#   'look',
#   'look_like',
#   'moment',
#   'mother',
#   'overall',
#   'picture',
#   'picture_show',
#   'pictures',
#   'place',
#   'placed',
#   'really',
#   'relax',
#   'relaxing',
#   'scene',
#   'second',
#   'show',
#   'showcase',
#   'showcases',
#   'shows',
#   'sit',
#   'sitting',
#   'spend',
#   'spend_time',
#   'spending_time',
#   'suggest',
#   'suggesting',
#   'time',
#   'two',
#   'twos',
#   'use',
#   'using',
#   'woman'],
#  12785: ['acrobatic',
#   'acrobatic_stunt',
#   'acrobatics',
#   'activity',
#   'air',
#   'appear',
#   'boy',
#   'boys',
#   'energetic',
#   'energetic_activity',
#   'engage',
#   'engaged',
#   'enjoy',
#   'enjoying',
#   'field',
#   'find',
#   'found',
#   'fun',
#   'grand',
#   'grassy',
#   'grassy_field',
#   'ground',
#   'ol',
#   'old',
#   'old_photos',
#   'parent',
#   'parents',
#   'perform',
#   'performing',
#   'photo',
#   'playful',
#   'quad',
#   'stunt',
#   'stunts',
#   'two',
#   'twos',
#   'young',
#   'young_boy',
#   'young_boys'],
#  21053: ['appear',
#   'appears',
#   'baby',
#   'baby_boy',
#   'background',
#   'backyard',
#   'beater',
#   'beaters',
#   'birthday',
#   'birthday_cake',
#   'birthday_party',
#   'blow',
#   'boy',
#   'cake',
#   'candle',
#   'candles',
#   'celebrate',
#   'celebrating',
#   'cover',
#   'covering',
#   'day',
#   'dick',
#   'enjoy',
#   'enjoying',
#   'face',
#   'goat',
#   'hand',
#   'hands',
#   'hat',
#   'head',
#   'help',
#   'helping',
#   'hold',
#   'holding',
#   'image',
#   'keep',
#   'little',
#   'little_one',
#   'little_ones',
#   'outdoors',
#   'park',
#   'party',
#   'party_hat',
#   'place',
#   'rag',
#   'scene',
#   'seem',
#   'special',
#   'special_day',
#   'specialest',
#   'take',
#   'take_place',
#   'takes',
#   'takes_place',
#   'tell',
#   'time',
#   'together',
#   'told',
#   'tree',
#   'treed',
#   'trees',
#   'visible',
#   'wear',
#   'wearing',
#   'woman'],
#  53260: ['alcohol',
#   'alcoholic',
#   'alcoholic_beverage',
#   'alcoholic_beverages',
#   'appear',
#   'appears',
#   'atmosphere',
#   'background',
#   'bar',
#   'beverage',
#   'beverages',
#   'bottle',
#   'bottled',
#   'company',
#   'consume',
#   'consume_alcoholic_beverages',
#   'consuming',
#   'conversation',
#   'drank',
#   'drink',
#   'drinks',
#   'engage',
#   'enjoy',
#   'enjoying',
#   'enjoying_drink',
#   'gather',
#   'gathering',
#   'good',
#   'good_time',
#   'group',
#   'hand',
#   'hold',
#   'holding',
#   'joke',
#   'laugh',
#   'laughing',
#   'lively',
#   'man',
#   'may',
#   'men',
#   'might',
#   'muslim',
#   'muslims',
#   'one_man',
#   'sit',
#   'sitting',
#   'smile',
#   'smiling',
#   'social',
#   'social_gathering',
#   'suggest',
#   'suggesting',
#   'three',
#   'time',
#   'together',
#   'visible',
#   'walk'],
#  41502: ['cover',
#   'covering',
#   'december',
#   'eye',
#   'eyes',
#   'face',
#   'headpiece',
#   'jihadi',
#   'miss',
#   'ornate',
#   'reveal',
#   'revealing',
#   'veil',
#   'wear',
#   'wearing',
#   'woman',
#   'woman_wear'],
#  50674: ['address',
#   'addressing',
#   'appear',
#   'appears',
#   'audience',
#   'blue',
#   'carpet',
#   'crowd',
#   'dress',
#   'dressed',
#   'event',
#   'front',
#   'gesture',
#   'gestures',
#   'hand',
#   'hands',
#   'image',
#   'joe',
#   'keep',
#   'kept',
#   'man',
#   'one_time',
#   'outfit',
#   'people',
#   'political',
#   'political_event',
#   'purple',
#   'raise',
#   'raising',
#   'rally',
#   'response',
#   'scene',
#   'several',
#   'several_people',
#   'speech',
#   'stand',
#   'standing',
#   'suit',
#   'tie',
#   'time',
#   'wave',
#   'waving',
#   'wear',
#   'wearing',
#   'woman'],
#  6859: ['add',
#   'adding',
#   'appear',
#   'appears',
#   'atmosphere',
#   'blue',
#   'deliver',
#   'delivers',
#   'enjoy',
#   'enjoying',
#   'entire',
#   'event',
#   'germany',
#   'got',
#   'great',
#   'great_war',
#   'hand',
#   'highlight',
#   'highlighting',
#   'hold',
#   'holding',
#   'illuminate',
#   'illuminated',
#   'kill',
#   'killed',
#   'left',
#   'man',
#   'mans',
#   'microphone',
#   'million',
#   'millions',
#   'moment',
#   'number',
#   'numbers',
#   'overall',
#   'performance',
#   'point',
#   'pointing',
#   'presence',
#   'pump',
#   'right',
#   'right_hand',
#   'right_handed',
#   'shirt',
#   'smile',
#   'smiling',
#   'speech',
#   'spotlight',
#   'spotlights',
#   'stage',
#   'stand',
#   'standing',
#   'upwards',
#   'war',
#   'wear',
#   'wearing',
#   'world'],
#  95164: ['belgium',
#   'grand',
#   'life',
#   'like',
#   'live',
#   'march',
#   'place',
#   'time',
#   'times'],
#  26495: ['also',
#   'appear',
#   'appears',
#   'back',
#   'book',
#   'book_place',
#   'chair',
#   'computer',
#   'cover',
#   'covering',
#   'desk',
#   'deskest',
#   'face',
#   'front',
#   'frustrate',
#   'frustrated',
#   'goat',
#   'hand',
#   'hat',
#   'laptop',
#   'laptop_computer',
#   'lean',
#   'lean_back',
#   'leaning',
#   'man',
#   'may',
#   'might',
#   'place',
#   'placed',
#   'relate',
#   'related',
#   'sit',
#   'sitting',
#   'stress',
#   'stressed',
#   'studies',
#   'study',
#   'suggest',
#   'suggesting',
#   'task',
#   'tasks',
#   'tell',
#   'tells',
#   'use',
#   'using',
#   'various',
#   'wear',
#   'wearing',
#   'work',
#   'working'],
#  13470: ['additionally',
#   'appear',
#   'appears',
#   'background',
#   'burn',
#   'burning',
#   'capture',
#   'capturing',
#   'cell',
#   'cell_phone',
#   'center',
#   'clock',
#   'communicate',
#   'congress',
#   'defund',
#   'depict',
#   'depicts',
#   'event',
#   'events',
#   'feature',
#   'features',
#   'first',
#   'front',
#   'gather',
#   'gathered',
#   'group',
#   'hijab',
#   'hold',
#   'holding',
#   'homeland',
#   'homeland_security',
#   'image',
#   'indicate',
#   'indicating',
#   'moment',
#   'muslim',
#   'muslims',
#   'one_person',
#   'people',
#   'people_gather',
#   'people_gathered',
#   'person',
#   'phone',
#   'photo',
#   'photos',
#   'room',
#   'seat',
#   'seated',
#   'second',
#   'security',
#   'several',
#   'several_people',
#   'stand',
#   'standing',
#   'television',
#   'time',
#   'tower',
#   'towers',
#   'trade',
#   'two',
#   'twos',
#   'unfold',
#   'visible',
#   'watch',
#   'watching',
#   'wear',
#   'wearing',
#   'woman',
#   'woman_wear',
#   'world',
#   'world_trade',
#   'world_trade_center'],
#  25874: ['additionally',
#   'aerial',
#   'aerial_view',
#   'along',
#   'appeal',
#   'appeals',
#   'atmosphere',
#   'away',
#   'build',
#   'building',
#   'buildings',
#   'busy',
#   'capture',
#   'captures',
#   'car',
#   'car_park',
#   'cars',
#   'circuit',
#   'circuit_court',
#   'city',
#   'close',
#   'closer',
#   'conservative',
#   'conservatives',
#   'court',
#   'create',
#   'creating',
#   'environment',
#   'far',
#   'far_away',
#   'feature',
#   'features',
#   'fire',
#   'fire_hydrant',
#   'flow',
#   'hydrant',
#   'image',
#   'indicate',
#   'indicating',
#   'intersect',
#   'intersecting',
#   'intersection',
#   'large',
#   'large_city',
#   'light',
#   'line',
#   'lined',
#   'locate',
#   'located',
#   'overall',
#   'park',
#   'parked',
#   'picture',
#   'riot',
#   'rule',
#   'ruling',
#   'see',
#   'seen',
#   'several',
#   'side',
#   'sides',
#   'street',
#   'streets',
#   'tall',
#   'tall_building',
#   'tall_buildings',
#   'traffic',
#   'traffic_light',
#   'two',
#   'twos',
#   'urban',
#   'urban_environment',
#   'view'],
#  48120: ['affect',
#   'affected',
#   'aftermath',
#   'another',
#   'ape',
#   'aped',
#   'apes',
#   'appear',
#   'appears',
#   'atmosphere',
#   'debris',
#   'disaster',
#   'earthquake',
#   'find',
#   'food',
#   'image',
#   'injure',
#   'injured',
#   'interact',
#   'interacting',
#   'left',
#   'may',
#   'might',
#   'monkey',
#   'monkey_might',
#   'monkeys',
#   'natural',
#   'natural_disaster',
#   'overall',
#   'pile',
#   'place',
#   'planet',
#   'rest',
#   'right',
#   'right_side',
#   'rise',
#   'safe',
#   'safe_place',
#   'scene',
#   'scene_one',
#   'search',
#   'searching',
#   'seem',
#   'side',
#   'stand',
#   'standing',
#   'state',
#   'struggle',
#   'struggling',
#   'suggest',
#   'suggests',
#   'survive',
#   'top',
#   'traumatize',
#   'traumatized',
#   'try',
#   'trying',
#   'tsunami',
#   'two',
#   'twos',
#   'visible'],
#  28395: ['activities',
#   'activity',
#   'another',
#   'appear',
#   'date',
#   'depict',
#   'depicting',
#   'different',
#   'eat',
#   'eating',
#   'engage',
#   'engaging',
#   'feature',
#   'features',
#   'first',
#   'flower',
#   'fun',
#   'ill',
#   'illest',
#   'image',
#   'least',
#   'leastest',
#   'multiple',
#   'nature',
#   'picture',
#   'pictures',
#   'play',
#   'playful',
#   'playing',
#   'present',
#   'scene',
#   'second',
#   'show',
#   'showcase',
#   'showcasing',
#   'side',
#   'squirrel',
#   'squirrels',
#   'three',
#   'two',
#   'twos',
#   'various',
#   'visible',
#   'wait',
#   'well'],
#  31526: ['bottle',
#   'bottled',
#   'boy',
#   'clean',
#   'clean_water',
#   'drank',
#   'drink',
#   'drinking',
#   'food',
#   'meanwhile',
#   'much',
#   'much_food',
#   'starve',
#   'starving',
#   'waste',
#   'water',
#   'water_bottle',
#   'young',
#   'young_boy'],
#  2631: ['additionally',
#   'annoy',
#   'annoyed',
#   'appear',
#   'appears',
#   'away',
#   'background',
#   'beautiful',
#   'big',
#   'blonde',
#   'blue',
#   'blue_sky',
#   'capture',
#   'captures',
#   'directly',
#   'dishevel',
#   'disheveled',
#   'emotion',
#   'emotional',
#   'emotional_state',
#   'emphasize',
#   'emphasizing',
#   'eye',
#   'eyes',
#   'first',
#   'first_time',
#   'front',
#   'frustrate',
#   'frustrated',
#   'frustration',
#   'fucking',
#   'grandma',
#   'hair',
#   'hand',
#   'hands',
#   'hold',
#   'holding',
#   'image',
#   'indicate',
#   'indicating',
#   'involve',
#   'involved',
#   'left',
#   'main',
#   'messy',
#   'moment',
#   'mouth',
#   'open',
#   'overall',
#   'people',
#   'right',
#   'right_side',
#   'scene',
#   'see',
#   'sees',
#   'side',
#   'sky',
#   'stand',
#   'standing',
#   'state',
#   'struggle',
#   'struggles',
#   'tension',
#   'time',
#   'two',
#   'twos',
#   'visible',
#   'walk',
#   'walk_away',
#   'walking',
#   'week',
#   'whole',
#   'wide',
#   'woman'],
#  37296: ['activity',
#   'adult',
#   'also',
#   'another',
#   'another_person',
#   'appear',
#   'appears',
#   'board',
#   'boy',
#   'carefully',
#   'cut',
#   'cut_boards',
#   'cutting',
#   'cutting_board',
#   'depict',
#   'depicts',
#   'engage',
#   'engaging',
#   'enjoy',
#   'enjoying',
#   'fun',
#   'help',
#   'image',
#   'indicate',
#   'indicating',
#   'knife',
#   'nearby',
#   'overall',
#   'person',
#   'person_nearby',
#   'piece',
#   'pieces',
#   'prepare',
#   'prepares',
#   'preparing',
#   'present',
#   'process',
#   'sandwich',
#   'sandwich_spread',
#   'sandwiches',
#   'scene',
#   'several',
#   'small',
#   'small_piece',
#   'spread',
#   'use',
#   'using',
#   'wooden',
#   'young',
#   'young_boy'],
#  42153: ['addition',
#   'appear',
#   'appears',
#   'beard',
#   'bearded',
#   'build',
#   'center',
#   'different',
#   'emphasize',
#   'emphasizing',
#   'feature',
#   'features',
#   'hat',
#   'house',
#   'houses',
#   'image',
#   'left',
#   'man',
#   'object',
#   'pebble',
#   'photo',
#   'photos',
#   'position',
#   'positioned',
#   'presence',
#   'right',
#   'right_side',
#   'rock',
#   'rocklike',
#   'scene',
#   'shirt',
#   'side',
#   'small',
#   'small_stone',
#   'stone',
#   'two',
#   'twos',
#   'wear',
#   'wearing',
#   'white'],
#  60487: ['add',
#   'adding',
#   'area',
#   'away',
#   'beauty',
#   'body',
#   'brightly',
#   'cast',
#   'casting',
#   'close',
#   'closer',
#   'depict',
#   'depicts',
#   'entire',
#   'far',
#   'far_away',
#   'glow',
#   'hill',
#   'hills',
#   'image',
#   'imagine',
#   'lake',
#   'landscape',
#   'large',
#   'large_body',
#   'least',
#   'leastest',
#   'mountain',
#   'mountains',
#   'muslim',
#   'muslims',
#   'natural',
#   'nine',
#   'peace',
#   'position',
#   'positioned',
#   'roll',
#   'rolling',
#   'scatter',
#   'scattered',
#   'scene',
#   'serene',
#   'several',
#   'shine',
#   'shine_brightly',
#   'shining',
#   'shining_brightly',
#   'shone',
#   'sky',
#   'sun',
#   'surround',
#   'surrounded',
#   'throughout',
#   'total',
#   'tree',
#   'treed',
#   'trees',
#   'visible',
#   'warm',
#   'water',
#   'world'],
#  28396: ['beach',
#   'hat',
#   'pink',
#   'pose',
#   'posing',
#   'string',
#   'tampon',
#   'tampons',
#   'trip',
#   'trips',
#   'wear',
#   'woman'],
#  48123: ['atomic',
#   'atomic_bomb',
#   'bomb',
#   'bright',
#   'cloud',
#   'clouded',
#   'cure',
#   'dark',
#   'explosion',
#   'glow',
#   'glowing',
#   'islam',
#   'mushroom',
#   'mushroom_cloud'],
#  71824: ['aspect',
#   'aspects',
#   'attention',
#   'baby',
#   'care',
#   'collage',
#   'depict',
#   'depicting',
#   'different',
#   'feature',
#   'features',
#   'field',
#   'first',
#   'give',
#   'given',
#   'glove',
#   'gloves',
#   'go',
#   'gown',
#   'gowns',
#   'group',
#   'highlight',
#   'highlighting',
#   'hold',
#   'holding',
#   'hospital',
#   'image',
#   'medical',
#   'medical_professional',
#   'newborn',
#   'newborns',
#   'okay',
#   'one_person',
#   'operating_room',
#   'overall',
#   'patient',
#   'patients',
#   'people',
#   'people_wear',
#   'person',
#   'person_held',
#   'piece',
#   'professional',
#   'professionals',
#   'room',
#   'scene',
#   'scenes',
#   'scrub',
#   'scrubs',
#   'second',
#   'set',
#   'setting',
#   'shit',
#   'show',
#   'showcase',
#   'showcases',
#   'shows',
#   'surgical',
#   'surgical_gown',
#   'third',
#   'three',
#   'together',
#   'two',
#   'two_people',
#   'twos',
#   'various',
#   'wear',
#   'wearing',
#   'woman',
#   'woman_wear',
#   'work',
#   'work_together',
#   'working',
#   'working_together'],
#  27068: ['add',
#   'additionally',
#   'backdrop',
#   'binocular',
#   'binoculars',
#   'black',
#   'bomb',
#   'collage',
#   'cover',
#   'covering',
#   'depict',
#   'depicts',
#   'different',
#   'element',
#   'elements',
#   'face',
#   'feature',
#   'features',
#   'first',
#   'front',
#   'globe',
#   'go',
#   'hijab',
#   'hold',
#   'holding',
#   'hoodie',
#   'image',
#   'intriguing',
#   'jihad',
#   'jihads',
#   'knife',
#   'left',
#   'locate',
#   'located',
#   'man',
#   'map',
#   'mysterious',
#   'nature',
#   'pair',
#   'position',
#   'positioned',
#   'right',
#   'right_side',
#   'scarf',
#   'scene',
#   'scenes',
#   'second',
#   'set',
#   'several',
#   'side',
#   'two',
#   'twos',
#   'wear',
#   'wearing',
#   'went',
#   'within',
#   'woman',
#   'woman_wear',
#   'world',
#   'world_map'],
#  18546: ['air',
#   'appear',
#   'appears',
#   'attend',
#   'attending',
#   'background',
#   'behind',
#   'behindest',
#   'black',
#   'black_suit',
#   'body',
#   'deliver',
#   'delivering',
#   'demand',
#   'display',
#   'displaying',
#   'event',
#   'front',
#   'give',
#   'giving',
#   'hand',
#   'hands',
#   'hard',
#   'hit',
#   'hits',
#   'image',
#   'large',
#   'listen',
#   'listening',
#   'man',
#   'mans',
#   'people',
#   'position',
#   'positioned',
#   'presentation',
#   'raise',
#   'raised',
#   'right',
#   'right_side',
#   'screen',
#   'several',
#   'shirt',
#   'side',
#   'speech',
#   'stage',
#   'stand',
#   'standing',
#   'suit',
#   'towards',
#   'visible',
#   'wear',
#   'wearing',
#   'weed',
#   'white',
#   'word'],
#  78321: ['another',
#   'another_man',
#   'depict',
#   'depicting',
#   'engraving',
#   'fit',
#   'fits',
#   'front',
#   'group',
#   'hold',
#   'holding',
#   'kneel',
#   'kneeling',
#   'man',
#   'men',
#   'one_man',
#   'ship',
#   'ships',
#   'whip'],
#  37864: ['anniversary',
#   'appear',
#   'best',
#   'birthday',
#   'cafe',
#   'celebrate',
#   'celebrating',
#   'company',
#   'conversation',
#   'dining_tables',
#   'engage',
#   'engaging',
#   'enjoy',
#   'enjoying',
#   'gift',
#   'give',
#   'giving',
#   'good',
#   'headscarf',
#   'hijab',
#   'holiday',
#   'man',
#   'muslim',
#   'muslims',
#   'occasion',
#   'pleasant',
#   'pleasant_conversation',
#   'pleasantest',
#   'setting',
#   'sit',
#   'sitting',
#   'special',
#   'special_occasion',
#   'specialest',
#   'suggest',
#   'suggests',
#   'table',
#   'wear',
#   'wearing',
#   'woman'],
#  95163: ['accident',
#   'accidents',
#   'belt',
#   'car',
#   'car_accident',
#   'car_accidents',
#   'design',
#   'less',
#   'new',
#   'put',
#   'putting',
#   'seat',
#   'seat_belt',
#   'seatbelt',
#   'woman'],
#  9386: ['add',
#   'adds',
#   'appear',
#   'appears',
#   'background',
#   'capture',
#   'capturing',
#   'colorful',
#   'dark',
#   'dark_hair',
#   'enjoy',
#   'enjoying',
#   'essence',
#   'face',
#   'gas',
#   'gas_prices',
#   'go',
#   'good',
#   'good_time',
#   'hair',
#   'happiness',
#   'image',
#   'long',
#   'moment',
#   'outfit',
#   'playful',
#   'pose',
#   'posing',
#   'positivity',
#   'price',
#   'prices',
#   'red',
#   'smile',
#   'smiling',
#   'stripe',
#   'striped',
#   'tank',
#   'tank_top',
#   'time',
#   'top',
#   'touch',
#   'vibrant',
#   'wear',
#   'wearing',
#   'woman',
#   'young',
#   'young_woman'],
#  76814: ['also',
#   'appear',
#   'apron',
#   'assist',
#   'assisted',
#   'best',
#   'bowl',
#   'boy',
#   'chef',
#   'chefs',
#   'cook',
#   'create',
#   'creating',
#   'delicious',
#   'delicious_meal',
#   'enjoy',
#   'enjoyable',
#   'enjoying',
#   'experience',
#   'good',
#   'hat',
#   'image',
#   'ingredient',
#   'ingredients',
#   'kitchen',
#   'meal',
#   'mix',
#   'mix_ingredients',
#   'mixing_ingredients',
#   'mother',
#   'positive',
#   'prepare',
#   'prepares',
#   'process',
#   'seem',
#   'smile',
#   'smiling',
#   'son',
#   'syndrome',
#   'together',
#   'wear',
#   'wearing',
#   'young',
#   'young_boy'],
#  64297: ['black',
#   'jewish',
#   'kid',
#   'ol',
#   'old',
#   'oven',
#   'ovens',
#   'photograph',
#   'photographed',
#   'roast',
#   'roasts',
#   'room',
#   'several',
#   'squad',
#   'white',
#   'whole'],
#  56108: ['angry',
#   'appear',
#   'appears',
#   'attentively',
#   'chimpanzee',
#   'front',
#   'give',
#   'giving',
#   'image',
#   'listen',
#   'listen_attentively',
#   'listening',
#   'michelle',
#   'microphone',
#   'monkey',
#   'mouth',
#   'mouth_open',
#   'next',
#   'obama',
#   'open',
#   'photo',
#   'photos',
#   'presentation',
#   'react',
#   'reacting',
#   'sit',
#   'sitting',
#   'speech',
#   'stand',
#   'standing',
#   'two',
#   'twos',
#   'woman'],
#  98310: ['chimney',
#   'front',
#   'gather',
#   'gathered',
#   'group',
#   'hat',
#   'hats',
#   'jewish',
#   'length',
#   'listen',
#   'listening',
#   'man',
#   'mask',
#   'masks',
#   'measure',
#   'men',
#   'microphone',
#   'speak',
#   'speaking',
#   'speed',
#   'surgical',
#   'surgical_mask',
#   'tent',
#   'velocity',
#   'wear',
#   'wearing',
#   'wind',
#   'x'],
#  76815: ['add',
#   'adding',
#   'appear',
#   'appears',
#   'atmosphere',
#   'background',
#   'capture',
#   'captures',
#   'chick',
#   'coffee',
#   'cup',
#   'elderly',
#   'elderly_woman',
#   'enjoy',
#   'enjoying',
#   'fish',
#   'hand',
#   'hat',
#   'hold',
#   'holding',
#   'image',
#   'lake',
#   'leisure',
#   'man',
#   'moment',
#   'near',
#   'peaceful',
#   'relaxation',
#   'scene',
#   'sit',
#   'sitting',
#   'stand',
#   'tranquil',
#   'water',
#   'wear',
#   'wearing',
#   'woman'],
#  59840: ['bed',
#   'bed_cover',
#   'blanket',
#   'child',
#   'cover',
#   'covered',
#   'game',
#   'gamed',
#   'games',
#   'hunger',
#   'hunger_games',
#   'lay',
#   'laying',
#   'malnutrition',
#   'severe',
#   'show',
#   'showing',
#   'sign',
#   'signs',
#   'towel',
#   'towels',
#   'win',
#   'winning'],
#  76819: ['additionally',
#   'appear',
#   'appears',
#   'atmosphere',
#   'background',
#   'body',
#   'camera',
#   'close',
#   'closer',
#   'create',
#   'creating',
#   'dance',
#   'dreadlock',
#   'dreadlocks',
#   'edge',
#   'image',
#   'jean',
#   'jeans',
#   'kid',
#   'kids',
#   'left',
#   'less',
#   'light',
#   'lights',
#   'man',
#   'mans',
#   'maybe',
#   'microphone',
#   'microphones',
#   'music',
#   'musician',
#   'musicians',
#   'near',
#   'obscure',
#   'obscured',
#   'overpaid',
#   'overpay',
#   'partially',
#   'performance',
#   'place',
#   'placed',
#   'plaid',
#   'pose',
#   'posing',
#   'position',
#   'positioned',
#   'rapper',
#   'rappers',
#   'right',
#   'right_side',
#   'several',
#   'shirt',
#   'shitty',
#   'side',
#   'smart',
#   'stage',
#   'stand',
#   'standing',
#   'teacher',
#   'teachers',
#   'two',
#   'twos',
#   'underpaid',
#   'vibrant',
#   'wear',
#   'wearing'],
#  98314: ['also',
#   'attend',
#   'attending',
#   'background',
#   'bernie',
#   'collage',
#   'different',
#   'donald',
#   'event',
#   'figure',
#   'figures',
#   'give',
#   'giving',
#   'government',
#   'government_pay',
#   'gun',
#   'guns',
#   'healthcare',
#   'hold',
#   'holding',
#   'image',
#   'include',
#   'including',
#   'listen',
#   'listening',
#   'pay',
#   'people',
#   'podia',
#   'podium',
#   'political',
#   'political_figure',
#   'pose',
#   'poses',
#   'president',
#   'rifle',
#   'right',
#   'sand',
#   'sanders',
#   'senator',
#   'several',
#   'several_people',
#   'show',
#   'shown',
#   'speech',
#   'speeches',
#   'total',
#   'trump',
#   'various',
#   'visible'],
#  10574: ['amazing',
#   'appear',
#   'back',
#   'backdrop',
#   'background',
#   'boy',
#   'boys',
#   'build',
#   'capture',
#   'capturing',
#   'carry',
#   'carrying',
#   'costume',
#   'costumes',
#   'credit',
#   'dangle',
#   'dangling',
#   'enjoy',
#   'enjoying',
#   'essence',
#   'feature',
#   'features',
#   'fun',
#   'get',
#   'got',
#   'happen',
#   'image',
#   'job',
#   'kid',
#   'kids',
#   'last',
#   'last_year',
#   'leg',
#   'legs',
#   'man',
#   'moment',
#   'new',
#   'new_job',
#   'pink',
#   'playful',
#   'scene',
#   'seem',
#   'serve',
#   'serves',
#   'shoulder',
#   'shoulders',
#   'smile',
#   'smiling',
#   'something_amazing',
#   'spend',
#   'start',
#   'started',
#   'superhero',
#   'time',
#   'together',
#   'tyrone',
#   'wall',
#   'wear',
#   'wearing',
#   'year',
#   'young',
#   'young_boy'],
#  27069: ['amsterdam',
#   'around',
#   'behind',
#   'behindest',
#   'close',
#   'closer',
#   'dirt',
#   'dirt_road',
#   'district',
#   'either',
#   'feature',
#   'features',
#   'first',
#   'follow',
#   'following',
#   'front',
#   'gather',
#   'gather_around',
#   'goat',
#   'goats',
#   'group',
#   'herd',
#   'house',
#   'image',
#   'interact',
#   'interacting',
#   'light',
#   'man',
#   'photo',
#   'photos',
#   'position',
#   'positioned',
#   'red',
#   'red_light',
#   'red_light_district',
#   'road',
#   'second',
#   'seem',
#   'several',
#   'show',
#   'shows',
#   'stand',
#   'standing',
#   'surround',
#   'surrounded',
#   'surrounding',
#   'surroundings',
#   'two',
#   'twos',
#   'visible',
#   'walk',
#   'walking',
#   'woman'],
#  17235: ['action',
#   'bathroom',
#   'brown',
#   'close',
#   'condition',
#   'conditions',
#   'emphasize',
#   'emphasizing',
#   'finger',
#   'flush',
#   'flushed',
#   'hand',
#   'handle',
#   'hygiene',
#   'image',
#   'important',
#   'indicate',
#   'indicating',
#   'maintain',
#   'maintaining',
#   'need',
#   'needs',
#   'person',
#   'persons',
#   'persons_hand',
#   'point',
#   'pointing',
#   'position',
#   'positioned',
#   'possible',
#   'proper',
#   'sanitary',
#   'sanitary_condition',
#   'soon',
#   'toilet',
#   'towards'],
#  85346: ['allah',
#   'appear',
#   'appears',
#   'background',
#   'belief',
#   'beliefs',
#   'body',
#   'body_language',
#   'concept',
#   'creative',
#   'creative_process',
#   'engage',
#   'engaged',
#   'express',
#   'expressing',
#   'expression',
#   'facial',
#   'facial_expression',
#   'faith',
#   'feature',
#   'features',
#   'hand',
#   'hijab',
#   'hold',
#   'holding',
#   'idea',
#   'image',
#   'language',
#   'muslim',
#   'pink',
#   'point',
#   'pointing',
#   'process',
#   'relate',
#   'related',
#   'sky',
#   'stand',
#   'standing',
#   'suggest',
#   'thoughtful',
#   'towards',
#   'upwards',
#   'watch',
#   'watching',
#   'wear',
#   'wearing',
#   'woman',
#   'woman_wear',
#   'young'],
#  72396: ['appear',
#   'back',
#   'blanket',
#   'chest',
#   'company',
#   'cuddle',
#   'cuddled',
#   'embrace',
#   'embracing',
#   'enjoy',
#   'enjoying',
#   'fucking',
#   'head',
#   'intimate',
#   'kiss',
#   'kissing',
#   'lay',
#   'lie',
#   'lying',
#   'man',
#   'men',
#   'moment',
#   'queer',
#   'queers',
#   'rest',
#   'resting',
#   'two',
#   'two_man',
#   'two_men',
#   'twos',
#   'white'],
#  19820: ['add',
#   'adding',
#   'admit',
#   'also',
#   'america',
#   'atmosphere',
#   'background',
#   'blanket',
#   'consist',
#   'consisting',
#   'conversation',
#   'drank',
#   'drink',
#   'drinks',
#   'engage',
#   'engaging',
#   'enjoy',
#   'enjoying',
#   'family',
#   'family_member',
#   'family_members',
#   'field',
#   'four',
#   'fruit',
#   'fruits',
#   'grassy',
#   'grassy_field',
#   'image',
#   'interact',
#   'interacting',
#   'meal',
#   'member',
#   'members',
#   'outdoor',
#   'peaceful',
#   'picnic',
#   'picnicked',
#   'pond',
#   'sandwich',
#   'sandwiches',
#   'scene',
#   'serene',
#   'share',
#   'sit',
#   'sitting',
#   'together',
#   'visible',
#   'well',
#   'white'],
#  14726: ['appear',
#   'background',
#   'black',
#   'blue',
#   'chair',
#   'chairs',
#   'company',
#   'conversation',
#   'dealer',
#   'desk',
#   'deskest',
#   'drug',
#   'drug_dealer',
#   'engage',
#   'engaged',
#   'engaging',
#   'enjoy',
#   'enjoying',
#   'friendly',
#   'hold',
#   'holding',
#   'image',
#   'interaction',
#   'man',
#   'men',
#   'moment',
#   'next',
#   'office',
#   'one_man',
#   'place',
#   'plaid',
#   'positive',
#   'racist',
#   'scene',
#   'seem',
#   'set',
#   'setting',
#   'share',
#   'shirt',
#   'smile',
#   'smiling',
#   'stand',
#   'standing',
#   'take',
#   'take_place',
#   'takes',
#   'takes_place',
#   'tie',
#   'together',
#   'two',
#   'two_man',
#   'two_men',
#   'twos',
#   'visible',
#   'wear',
#   'wearing'],
#  72398: ['adolf',
#   'adolf_hitler',
#   'appear',
#   'appears',
#   'area',
#   'backdrop',
#   'background',
#   'black',
#   'boy',
#   'boys',
#   'capture',
#   'captures',
#   'cook',
#   'cook_one',
#   'dark',
#   'dark_area',
#   'darker_area',
#   'dictator',
#   'emphasize',
#   'emphasizing',
#   'expression',
#   'face',
#   'gas',
#   'gaze',
#   'germany',
#   'hitler',
#   'hitlers',
#   'ii',
#   'image',
#   'intense',
#   'jacket',
#   'know',
#   'leadership',
#   'nazi',
#   'nazi_germany',
#   'portrait',
#   'power',
#   'reign',
#   'serious',
#   'tie',
#   'turn',
#   'wall',
#   'war',
#   'wear',
#   'wearing',
#   'white',
#   'world',
#   'world_war',
#   'world_war_ii'],
#  71823: ['abuse',
#   'argue',
#   'arguing',
#   'attire',
#   'business',
#   'business_attire',
#   'domestic',
#   'domestic_abuse',
#   'end',
#   'floor',
#   'hallway',
#   'man',
#   'put',
#   'sit',
#   'sitting',
#   'stand',
#   'standing',
#   'woman'],
#  90756: ['attire',
#   'background',
#   'barack',
#   'barack_obama',
#   'black',
#   'capture',
#   'captures',
#   'couple',
#   'crowd',
#   'dark',
#   'dark_suit',
#   'dress',
#   'embrace',
#   'embracing',
#   'event',
#   'family',
#   'family_photos',
#   'first',
#   'first_lady',
#   'formal',
#   'formal_attire',
#   'front',
#   'image',
#   'lady',
#   'michelle',
#   'moment',
#   'obama',
#   'people',
#   'photo',
#   'president',
#   'scene',
#   'see',
#   'seen',
#   'share',
#   'special',
#   'special_moment',
#   'specialest',
#   'stand',
#   'standing',
#   'suit',
#   'together',
#   'wear',
#   'wearing',
#   'wife'],
#  46815: ['add',
#   'adding',
#   'addition',
#   'also',
#   'another',
#   'black',
#   'book',
#   'bracelet',
#   'bracelets',
#   'dress',
#   'el',
#   'feature',
#   'features',
#   'fifty',
#   'grey',
#   'hand',
#   'hands',
#   'hold',
#   'holding',
#   'image',
#   'james',
#   'left',
#   'multiple',
#   'outfit',
#   'psychopath',
#   'psychopaths',
#   'right',
#   'right_wrist',
#   'satan',
#   'scene',
#   'scene_one',
#   'shade',
#   'shades',
#   'stylish',
#   'title',
#   'titled',
#   'touch',
#   'two',
#   'twos',
#   'visible',
#   'watch',
#   'watches',
#   'wear',
#   'wearing',
#   'woman',
#   'woman_wear',
#   'wrist',
#   'wrists',
#   'write',
#   'written'],
#  71826: ['arm',
#   'arms',
#   'background',
#   'behind',
#   'behindest',
#   'black',
#   'black_people',
#   'blackboard',
#   'camera',
#   'chalkboard',
#   'class',
#   'cross',
#   'crossed',
#   'display',
#   'displays',
#   'eachother',
#   'educational',
#   'emphasize',
#   'emphasizing',
#   'equation',
#   'equations',
#   'far',
#   'front',
#   'indicate',
#   'indicating',
#   'involve',
#   'involved',
#   'like',
#   'man',
#   'math',
#   'math_teacher',
#   'mathematical',
#   'may',
#   'might',
#   'people',
#   'people_dont',
#   'plaid',
#   'pose',
#   'posing',
#   'profession',
#   'school',
#   'schools',
#   'setting',
#   'shirt',
#   'shoot',
#   'shot',
#   'smile',
#   'smiling',
#   'stand',
#   'standing',
#   'street',
#   'streets',
#   'teacher',
#   'wear',
#   'wearing',
#   'white',
#   'white_people'],
#  6291: ['bc', 'casket', 'lay', 'laying', 'throw', 'woman'],
#  36590: ['agree',
#   'appear',
#   'appears',
#   'attention',
#   'attire',
#   'background',
#   'ban',
#   'bani',
#   'black',
#   'camera',
#   'capture',
#   'capturing',
#   'closeup',
#   'color',
#   'colored',
#   'contrast',
#   'contrast_colors',
#   'contrasting',
#   'cover',
#   'directly',
#   'eye',
#   'eyes',
#   'face',
#   'faces',
#   'feature',
#   'features',
#   'focal',
#   'focal_point',
#   'gray',
#   'image',
#   'look',
#   'looking',
#   'muslim',
#   'niqab',
#   'offend',
#   'offends',
#   'point',
#   'provide',
#   'providing',
#   'shot',
#   'surface',
#   'veil',
#   'viewer',
#   'viewers',
#   'visible',
#   'wall',
#   'wear',
#   'wearing',
#   'woman',
#   'woman_wear',
#   'womans',
#   'women',
#   'worn'],
#  42693: ['aisle',
#   'another',
#   'apple',
#   'apple_banana',
#   'apples',
#   'background',
#   'banana',
#   'bananas',
#   'boy',
#   'broccoli',
#   'broccolis',
#   'carrot',
#   'carrots',
#   'cook',
#   'depict',
#   'depicts',
#   'enjoy',
#   'enjoyable',
#   'enjoying',
#   'experience',
#   'explore',
#   'explores',
#   'family',
#   'family_member',
#   'fruit',
#   'fruits',
#   'german',
#   'groceries',
#   'grocery',
#   'grocery_store',
#   'grocery_store_aisle',
#   'include',
#   'including',
#   'kid',
#   'laugh',
#   'laughing',
#   'learn',
#   'member',
#   'mother',
#   'oven',
#   'ovens',
#   'overall',
#   'positive',
#   'scene',
#   'see',
#   'seen',
#   'shop',
#   'stand',
#   'standing',
#   'store',
#   'surround',
#   'surrounded',
#   'teacher',
#   'today',
#   'use',
#   'various',
#   'various_fruits',
#   'vegetable',
#   'vegetables',
#   'well',
#   'woman',
#   'young',
#   'young_boy'],
#  41503: ['activities',
#   'activity',
#   'add',
#   'adding',
#   'appear',
#   'around',
#   'background',
#   'beautiful',
#   'beautiful_day',
#   'capture',
#   'captures',
#   'child',
#   'children',
#   'day',
#   'emphasize',
#   'emphasizing',
#   'engage',
#   'engaging',
#   'enjoy',
#   'enjoying',
#   'follower',
#   'followers',
#   'grass',
#   'grassed',
#   'group',
#   'image',
#   'importance',
#   'interact',
#   'interacting',
#   'jesus',
#   'laugh',
#   'laughing',
#   'life',
#   'live',
#   'lives',
#   'moment',
#   'natural',
#   'play',
#   'playing',
#   'pray',
#   'praying',
#   'presence',
#   'scene',
#   'see',
#   'seen',
#   'setting',
#   'sit',
#   'sitting',
#   'spend',
#   'spend_time',
#   'spending_time',
#   'stump',
#   'time',
#   'together',
#   'tree',
#   'tree_stump',
#   'treed',
#   'value',
#   'valuing',
#   'various',
#   'young'],
#  36592: ['also',
#   'around',
#   'attention',
#   'brexit',
#   'capture',
#   'capturing',
#   'come',
#   'comes',
#   'crowd',
#   'demonstration',
#   'eu',
#   'european',
#   'european_union',
#   'european_union_flag',
#   'flag',
#   'focal',
#   'focal_point',
#   'form',
#   'forms',
#   'hate',
#   'hold',
#   'holding',
#   'image',
#   'issue',
#   'issues',
#   'many',
#   'many_forms',
#   'people',
#   'place',
#   'point',
#   'political',
#   'political_issue',
#   'political_issues',
#   'protest',
#   'relate',
#   'related',
#   'scene',
#   'surround',
#   'surrounded',
#   'take',
#   'take_place',
#   'takes',
#   'takes_place',
#   'union',
#   'union_flag',
#   'vest',
#   'vests',
#   'wear',
#   'wearing',
#   'woman',
#   'yellow'],
#  75461: ['additionally',
#   'another',
#   'another_person',
#   'around',
#   'away',
#   'belt',
#   'car',
#   'car_engine',
#   'cars',
#   'center',
#   'coil',
#   'coiled',
#   'compartment',
#   'component',
#   'components',
#   'engine',
#   'engine_compartment',
#   'far',
#   'far_away',
#   'feature',
#   'features',
#   'hood',
#   'image',
#   'include',
#   'including',
#   'large',
#   'left',
#   'middle',
#   'near',
#   'one_person',
#   'open',
#   'part',
#   'parts',
#   'people',
#   'person',
#   'position',
#   'positioned',
#   'problem',
#   'red',
#   'red_car',
#   'reveal',
#   'revealing',
#   'right',
#   'right_side',
#   'scene',
#   'serpentine',
#   'serpentine_belt',
#   'several',
#   'several_people',
#   'side',
#   'size',
#   'snake',
#   'stand',
#   'standing',
#   'surround',
#   'surrounded',
#   'third',
#   'third_person',
#   'various',
#   'vintage',
#   'visible',
#   'well',
#   'wrong'],
#  36597: ['alcohol',
#   'also',
#   'another',
#   'another_man',
#   'appear',
#   'bar',
#   'black',
#   'black_people',
#   'bottle',
#   'bottled',
#   'bottles',
#   'collage',
#   'different',
#   'drank',
#   'drink',
#   'drinking',
#   'drinks',
#   'enjoy',
#   'enjoying',
#   'first',
#   'front',
#   'glass',
#   'image',
#   'man',
#   'men',
#   'people',
#   'scene',
#   'scenes',
#   'second',
#   'shot',
#   'shots',
#   'socialize',
#   'socializing',
#   'stand',
#   'standing',
#   'surround',
#   'surrounded',
#   'tie',
#   'two',
#   'twos',
#   'various',
#   'wear',
#   'wearing',
#   'white',
#   'white_people',
#   'wine',
#   'wine_glass'],
#  41506: ['account',
#   'add',
#   'additionally',
#   'announcement',
#   'another',
#   'appear',
#   'appears',
#   'atmosphere',
#   'body',
#   'body_language',
#   'clinton',
#   'email',
#   'email_server',
#   'emails',
#   'emphasize',
#   'emphasizing',
#   'expression',
#   'facial',
#   'facial_expression',
#   'front',
#   'gesture',
#   'gesturing',
#   'give',
#   'giving',
#   'hand',
#   'hands',
#   'hillary',
#   'image',
#   'importance',
#   'knowledge',
#   'language',
#   'left',
#   'man',
#   'microphone',
#   'microphones',
#   'mouth',
#   'name',
#   'near',
#   'news',
#   'obama',
#   'open',
# ...
#   'experiments',
#   'front',
#   'germany',
#   'hello',
#   'hellos',
#   'hitler',
#   'hitlers',
#   'ii',
#   'inner',
#   'inner_circle',
#   'left',
#   'man',
#   'may',
#   'member',
#   'members',
#   'men',
#   'might',
#   'nazi',
#   'nazi_germany',
#   'office',
#   'part',
#   'phone',
#   'photograph',
#   'photographed',
#   'presence',
#   'present',
#   'room',
#   'setting',
#   'side',
#   'staff',
#   'staff_member',
#   'stand',
#   'stand_behind',
#   'standing',
#   'suggest',
#   'suggests',
#   'suit',
#   'table',
#   'talk',
#   'talking',
#   'think',
#   'tie',
#   'two',
#   'twos',
#   'war',
#   'wear',
#   'wearing',
#   'white',
#   'world',
#   'world_war',
#   'world_war_ii'],
#  71839: ['barack',
#   'barack_obama',
#   'clear',
#   'front',
#   'give',
#   'giving',
#   'lay',
#   'let',
#   'lie',
#   'lying',
#   'microphone',
#   'never',
#   'obama',
#   'perfectly',
#   'president',
#   'speech',
#   'stop',
#   'stop_lying',
#   'sucker',
#   'suckers'],
#  27805: ['arab',
#   'become',
#   'car',
#   'drier',
#   'dry',
#   'law',
#   'laws',
#   'like',
#   'lobby',
#   'look',
#   'looking',
#   'majority',
#   'man',
#   'man_sitting',
#   'men',
#   'outbreed',
#   'share',
#   'sick',
#   'sit',
#   'sitting',
#   'suck',
#   'system',
#   'systems',
#   'tablet',
#   'takeover',
#   'three',
#   'welfare',
#   'western'],
#  56184: ['addition',
#   'appear',
#   'appears',
#   'asian',
#   'away',
#   'blow',
#   'blowing',
#   'breeze',
#   'capture',
#   'capturing',
#   'enjoy',
#   'enjoying',
#   'expression',
#   'eye',
#   'eyes',
#   'face',
#   'feature',
#   'features',
#   'focal',
#   'focal_point',
#   'give',
#   'go',
#   'go_home',
#   'good',
#   'good_time',
#   'hair',
#   'home',
#   'image',
#   'individual',
#   'individuals',
#   'joyful',
#   'laugh',
#   'laughing',
#   'laughs',
#   'left',
#   'locate',
#   'located',
#   'moment',
#   'nothing',
#   'one_person',
#   'people',
#   'person',
#   'point',
#   'right',
#   'right_side',
#   'scene',
#   'scene_one',
#   'side',
#   'situate',
#   'situated',
#   'smile',
#   'smiling',
#   'stone',
#   'stoned',
#   'tank',
#   'tank_top',
#   'time',
#   'top',
#   'two',
#   'twos',
#   'wear',
#   'wearing',
#   'white',
#   'woman',
#   'woman_wear'],
#  60574: ['appear',
#   'appears',
#   'attire',
#   'background',
#   'blind',
#   'build',
#   'building',
#   'buildings',
#   'busy',
#   'busy_city',
#   'came',
#   'city',
#   'city_street',
#   'come',
#   'environment',
#   'event',
#   'express',
#   'expressing',
#   'hand',
#   'hands',
#   'hip',
#   'hips',
#   'hook',
#   'hooked',
#   'indicate',
#   'indicating',
#   'kid',
#   'look',
#   'looking',
#   'love',
#   'lovin',
#   'man',
#   'may',
#   'middle',
#   'might',
#   'participate',
#   'participating',
#   'people',
#   'photo',
#   'place',
#   'pose',
#   'posing',
#   'scene',
#   'shirt',
#   'simply',
#   'stand',
#   'standing',
#   'store',
#   'street',
#   'suggest',
#   'superman',
#   'surround',
#   'surrounded',
#   'suspender',
#   'suspenders',
#   'take',
#   'take_place',
#   'takes',
#   'takes_place',
#   'urban',
#   'urban_environment',
#   'various',
#   'vehicle',
#   'vehicles',
#   'visible',
#   'wear',
#   'wearing'],
#  79053: ['additionally',
#   'away',
#   'bottle',
#   'bottled',
#   'close',
#   'closer',
#   'dirt',
#   'dirt_road',
#   'far',
#   'far_away',
#   'feet',
#   'foot',
#   'fuck',
#   'go',
#   'green',
#   'ground',
#   'hand',
#   'hill',
#   'hold',
#   'holding',
#   'image',
#   'jacket',
#   'lay',
#   'left',
#   'lie',
#   'line',
#   'lying',
#   'man',
#   'mans',
#   'near',
#   'point',
#   'pointing',
#   'property',
#   'property_line',
#   'right',
#   'right_hand',
#   'right_handed',
#   'road',
#   'scene',
#   'several',
#   'sheep',
#   'side',
#   'stand',
#   'standing',
#   'surround',
#   'surrounded',
#   'towards',
#   'visible',
#   'wear',
#   'wearing',
#   'yeah'],
#  59874: ['additionally',
#   'body',
#   'cartoon',
#   'chain',
#   'chains',
#   'character',
#   'comic',
#   'comic_strip',
#   'element',
#   'elements',
#   'feature',
#   'features',
#   'forget',
#   'forgot',
#   'hang',
#   'hanging',
#   'hard',
#   'hat',
#   'hung',
#   'image',
#   'left',
#   'man',
#   'may',
#   'might',
#   'neck',
#   'next',
#   'part',
#   'right',
#   'right_side',
#   'scene',
#   'scene_one',
#   'set',
#   'setting',
#   'side',
#   'stand',
#   'standing',
#   'statue',
#   'statues',
#   'story',
#   'strip',
#   'suggest',
#   'sunglass',
#   'sunglasses',
#   'thought',
#   'thoughts',
#   'two',
#   'twos',
#   'wear',
#   'wearing'],
#  31569: ['beard',
#   'bearded',
#   'camera',
#   'chamber',
#   'close',
#   'eat',
#   'eat_pussy',
#   'gas',
#   'gas_chamber',
#   'hair',
#   'long',
#   'long_hair',
#   'man',
#   'pussy',
#   'smile',
#   'smiling'],
#  52031: ['acknowledgement',
#   'add',
#   'additionally',
#   'another',
#   'another_person',
#   'appear',
#   'around',
#   'atmosphere',
#   'background',
#   'celebration',
#   'cheek',
#   'event',
#   'feature',
#   'features',
#   'gather',
#   'gathering',
#   'hand',
#   'hands',
#   'happen',
#   'happening',
#   'image',
#   'include',
#   'including',
#   'left',
#   'lively',
#   'man',
#   'part',
#   'people',
#   'person',
#   'persons',
#   'persons_hand',
#   'raise',
#   'raise_hand',
#   'raised',
#   'raising',
#   'right',
#   'right_side',
#   'scene',
#   'several',
#   'side',
#   'smile',
#   'smiling',
#   'something_happened',
#   'something_happening',
#   'suit',
#   'tattoo',
#   'tattooed',
#   'tie',
#   'two',
#   'twos',
#   'visible',
#   'wear',
#   'wearing'],
#  31570: ['another',
#   'another_man',
#   'appear',
#   'appears',
#   'back',
#   'background',
#   'backs',
#   'bee',
#   'bees',
#   'black',
#   'black_hat',
#   'braid',
#   'braids',
#   'brown',
#   'busy',
#   'control',
#   'controlling',
#   'edit',
#   'edits',
#   'en',
#   'en_masse',
#   'ens',
#   'face',
#   'facing',
#   'family',
#   'fear',
#   'feature',
#   'features',
#   'go',
#   'gone',
#   'hair',
#   'hair_style',
#   'hat',
#   'hats',
#   'hear',
#   'hive',
#   'image',
#   'jacket',
#   'know',
#   'like',
#   'long',
#   'man',
#   'masse',
#   'men',
#   'news',
#   'next',
#   'pant',
#   'pants',
#   'person',
#   'see',
#   'sees',
#   'shirt',
#   'short',
#   'stand',
#   'standing',
#   'style',
#   'styled',
#   'suit',
#   'suit_jacket',
#   'think',
#   'third',
#   'third_person',
#   'till',
#   'truth',
#   'two',
#   'two_man',
#   'two_men',
#   'twos',
#   'unless',
#   'unlesss',
#   'viewer',
#   'wear',
#   'wear_hat',
#   'wearing',
#   'woman'],
#  9418: ['adolf',
#   'adolf_hitler',
#   'also',
#   'arm',
#   'arms',
#   'ask',
#   'asks',
#   'black',
#   'death',
#   'deaths',
#   'depict',
#   'depicting',
#   'der',
#   'dictator',
#   'different',
#   'expression',
#   'facial',
#   'facial_expression',
#   'food',
#   'führer',
#   'german',
#   'germany',
#   'gesture',
#   'gestures',
#   'give',
#   'giving',
#   'go',
#   'group',
#   'groups',
#   'hand',
#   'hands',
#   'hitler',
#   'holocaust',
#   'ii',
#   'image',
#   'know',
#   'known',
#   'lead',
#   'led',
#   'million',
#   'millions',
#   'minority',
#   'minority_group',
#   'mom',
#   'nazi',
#   'nazi_germany',
#   'photograph',
#   'photographed',
#   'photographs',
#   'picture',
#   'picture_show',
#   'pictures',
#   'point',
#   'pointing',
#   'politician',
#   'raise',
#   'raising',
#   'result',
#   'resulted',
#   'role',
#   'several',
#   'show',
#   'sign',
#   'various',
#   'war',
#   'well',
#   'well_known',
#   'went',
#   'white',
#   'world',
#   'world_war',
#   'world_war_ii'],
#  98357: ['appear',
#   'appears',
#   'black',
#   'camera',
#   'carpet',
#   'christian',
#   'christians',
#   'donald',
#   'dress',
#   'event',
#   'feature',
#   'features',
#   'formal',
#   'formal_event',
#   'gala',
#   'image',
#   'porn',
#   'pose',
#   'posing',
#   'president',
#   'red',
#   'red_carpet',
#   'scene',
#   'smile',
#   'smiling',
#   'stand',
#   'standing',
#   'trump',
#   'two',
#   'two_women',
#   'twos',
#   'wear',
#   'wearing',
#   'white',
#   'woman',
#   'women'],
#  42187: ['appear',
#   'appears',
#   'around',
#   'atmosphere',
#   'attire',
#   'casual',
#   'casual_attire',
#   'company',
#   'cyril',
#   'dress',
#   'dressed',
#   'enjoy',
#   'enjoying',
#   'event',
#   'festive',
#   'gather',
#   'gathering',
#   'image',
#   'lively',
#   'majority',
#   'man',
#   'mind',
#   'people',
#   'room',
#   'sa',
#   'see',
#   'several',
#   'smile',
#   'smiling',
#   'stand',
#   'standing',
#   'steal',
#   'stealing',
#   'suit',
#   'suits',
#   'surround',
#   'surrounded',
#   'tell',
#   'tie',
#   'ties',
#   'told',
#   'wear',
#   'wear_suit',
#   'wearing'],
#  38527: ['appear',
#   'appears',
#   'best',
#   'best_way',
#   'blue',
#   'boy',
#   'boys',
#   'chew',
#   'chew_gum',
#   'chewing',
#   'chewing_gum',
#   'cooperate',
#   'cooperating',
#   'cut',
#   'cutting',
#   'engage',
#   'engaged',
#   'get',
#   'good',
#   'gum',
#   'hair',
#   'haircut',
#   'haircutting',
#   'home',
#   'man',
#   'place',
#   'process',
#   'room',
#   'salon',
#   'scene',
#   'scissor',
#   'scissors',
#   'shirt',
#   'take',
#   'take_place',
#   'takes',
#   'takes_place',
#   'use',
#   'use_scissors',
#   'using',
#   'using_scissors',
#   'way',
#   'wear',
#   'wearing',
#   'young',
#   'young_boy'],
#  98361: ['add',
#   'adding',
#   'addition',
#   'another',
#   'around',
#   'atmosphere',
#   'background',
#   'camel',
#   'confetti',
#   'couple',
#   'day',
#   'desert',
#   'dress',
#   'feature',
#   'features',
#   'festive',
#   'front',
#   'hump',
#   'hump_day',
#   'humping',
#   'image',
#   'left',
#   'man',
#   'people',
#   'piece',
#   'pieces',
#   'pose',
#   'posing',
#   'right',
#   'right_side',
#   'scatter',
#   'scattered',
#   'scene',
#   'several',
#   'shit',
#   'side',
#   'suit',
#   'two',
#   'twos',
#   'visible',
#   'wear',
#   'wearing',
#   'woman'],
#  3857: ['awake',
#   'cake',
#   'cheese',
#   'cherries',
#   'cherry',
#   'combination',
#   'cream',
#   'cream_cheese',
#   'create',
#   'creates',
#   'delicious',
#   'dessert',
#   'flavorful',
#   'fork',
#   'frost',
#   'frosting',
#   'indulge',
#   'invite',
#   'inviting',
#   'next',
#   'piece',
#   'place',
#   'placed',
#   'plate',
#   'red',
#   'red_velvet',
#   'red_velvet_cake',
#   'sit',
#   'sits',
#   'top',
#   'topped',
#   'velvet',
#   'viewer',
#   'visually',
#   'visually_appealing',
#   'white'],
#  58061: ['add',
#   'adding',
#   'appearance',
#   'arm',
#   'capture',
#   'captures',
#   'confident',
#   'essence',
#   'expressive',
#   'expressive_person',
#   'fashionable',
#   'front',
#   'hair',
#   'hand',
#   'hold',
#   'holding',
#   'identities',
#   'identity',
#   'image',
#   'individuality',
#   'left',
#   'messy',
#   'one_hand',
#   'person',
#   'purple',
#   'shirt',
#   'showcase',
#   'showcasing',
#   'stand',
#   'standing',
#   'style',
#   'styled',
#   'tattoo',
#   'tattooed',
#   'transfat',
#   'two',
#   'twos',
#   'unique',
#   'wall',
#   'way',
#   'wear',
#   'wearing',
#   'white',
#   'woman',
#   'yet'],
#  38529: ['addition',
#   'also',
#   'another',
#   'asshole',
#   'background',
#   'blonde',
#   'book',
#   'book_place',
#   'close',
#   'closer',
#   'customer',
#   'customer_service',
#   'cut',
#   'cutting',
#   'discover',
#   'discovered',
#   'discovery',
#   'element',
#   'elements',
#   'emphasize',
#   'emphasizing',
#   'expression',
#   'eye',
#   'eyes',
#   'face',
#   'feature',
#   'features',
#   'focus',
#   'focused',
#   'front',
#   'fuck',
#   'hand',
#   'image',
#   'interesting',
#   'left',
#   'mouth',
#   'near',
#   'open',
#   'pair',
#   'place',
#   'placed',
#   'position',
#   'positioned',
#   'present',
#   'relate',
#   'related',
#   'right',
#   'right_hand',
#   'right_handed',
#   'right_side',
#   'scene',
#   'scissor',
#   'scissors',
#   'see',
#   'seen',
#   'service',
#   'several',
#   'shirt',
#   'side',
#   'slightly',
#   'something_interesting',
#   'stand',
#   'standing',
#   'suggest',
#   'suggesting',
#   'surprised_expression',
#   'topic',
#   'trim',
#   'trimming',
#   'unexpected',
#   'wear',
#   'wearing',
#   'white',
#   'woman',
#   'woman_wear',
#   'womans',
#   'young'],
#  87351: ['asian',
#   'blue',
#   'boy',
#   'camera',
#   'directly',
#   'expression',
#   'face',
#   'home',
#   'leave',
#   'left',
#   'look',
#   'looking',
#   'realize',
#   'serious',
#   'shirt',
#   'stove',
#   'wear',
#   'wearing',
#   'young'],
#  86045: ['add',
#   'adding',
#   'africa',
#   'attire',
#   'beautiful',
#   'beauty',
#   'black',
#   'brown',
#   'camera',
#   'capture',
#   'captures',
#   'confidence',
#   'consist',
#   'consists',
#   'directly',
#   'elegance',
#   'expression',
#   'feature',
#   'features',
#   'front',
#   'get',
#   'got',
#   'headscarf',
#   'image',
#   'longsleeved',
#   'look',
#   'looking',
#   'looks',
#   'master',
#   'outfit',
#   'photograph',
#   'photographed',
#   'poise',
#   'pose',
#   'poses',
#   'scarf',
#   'serious',
#   'shirt',
#   'showcase',
#   'showcasing',
#   'skirt',
#   'stand',
#   'standing',
#   'stone',
#   'stone_wall',
#   'touch',
#   'traditional',
#   'wall',
#   'wear',
#   'wearing',
#   'white',
#   'woman',
#   'woman_wear'],
#  87352: ['additionally',
#   'air',
#   'appear',
#   'appears',
#   'arm',
#   'arms',
#   'background',
#   'black',
#   'black_jacket',
#   'body',
#   'celebration',
#   'competition',
#   'convey',
#   'conveys',
#   'die',
#   'died',
#   'display',
#   'displaying',
#   'energy',
#   'enthusiasm',
#   'excitement',
#   'express',
#   'expressing',
#   'extend',
#   'extended',
#   'fist',
#   'fistest',
#   'fists',
#   'game',
#   'game_show',
#   'gamed',
#   'hold',
#   'holding',
#   'image',
#   'include',
#   'including',
#   'jacket',
#   'jesus',
#   'jesus_died',
#   'left',
#   'man',
#   'mans',
#   'may',
#   'microphone',
#   'might',
#   'nothing',
#   'object',
#   'objects',
#   'overall',
#   'participate',
#   'participating',
#   'performance',
#   'position',
#   'positioned',
#   'raise',
#   'raised',
#   'raises',
#   'right',
#   'right_side',
#   'scene',
#   'screen',
#   'sense',
#   'show',
#   'side',
#   'sin',
#   'stage',
#   'stand',
#   'standing',
#   'surround',
#   'surrounded',
#   'television',
#   'towards',
#   'use',
#   'using',
#   'various',
#   'various_objects',
#   'visible',
#   'wear',
#   'wearing'],
#  81529: ['acceptance',
#   'add',
#   'adding',
#   'atmosphere',
#   'beat',
#   'blue',
#   'blue_sky',
#   'capture',
#   'captures',
#   'celebrate',
#   'celebrates',
#   'clear',
#   'clear_blue',
#   'colorful',
#   'community',
#   'create',
#   'creating',
#   'elegance',
#   'equality',
#   'festive',
#   'flag',
#   'flags',
#   'fly',
#   'fly_high',
#   'flying',
#   'flying_high',
#   'flys',
#   'gate',
#   'gender',
#   'gender_identity',
#   'genderest',
#   'go',
#   'happy',
#   'high',
#   'identity',
#   'image',
#   'individual',
#   'individuals',
#   'iron',
#   'lesbian',
#   'lesbians',
#   'let',
#   'let_go',
#   'lets',
#   'lets_go',
#   'lgbtq',
#   'month',
#   'orientation',
#   'ornate',
#   'place',
#   'placed',
#   'pride',
#   'promote',
#   'promotes',
#   'rainbow',
#   'rainbow_flag',
#   'regardless',
#   'scene',
#   'sexual',
#   'sexual_orientation',
#   'sky',
#   'spirit',
#   'three',
#   'top',
#   'touch',
#   'vibrant'],
#  87364: ['appear',
#   'appears',
#   'ask',
#   'asked',
#   'back',
#   'background',
#   'body',
#   'camera',
#   'capture',
#   'captures',
#   'cast',
#   'contemplation',
#   'daydream',
#   'daydreaming',
#   'dress',
#   'engross',
#   'engrossed',
#   'face',
#   'facing',
#   'image',
#   'introspection',
#   'lean',
#   'leaning',
#   'lose',
#   'lost',
#   'moment',
#   'orange',
#   'probably',
#   'question',
#   'seem',
#   'seems',
#   'shadow',
#   'thought',
#   'thoughts',
#   'wall',
#   'wear',
#   'wearing',
#   'woman',
#   'wrong',
#   'young',
#   'young_woman'],
#  53278: ['additionally',
#   'another',
#   'appear',
#   'appears',
#   'away',
#   'close',
#   'enjoy',
#   'enjoying',
#   'far',
#   'far_away',
#   'first',
#   'goat',
#   'goatfucker',
#   'goats',
#   'ground',
#   'group',
#   'herd',
#   'image',
#   'indicate',
#   'indicating',
#   'laugh',
#   'laughs',
#   'lay',
#   'lie',
#   'lying',
#   'next',
#   'part',
#   'position',
#   'positioned',
#   'provide',
#   'provided',
#   'relax',
#   'relaxing',
#   'scene',
#   'shade',
#   'slightly',
#   'tree',
#   'tree_trunk',
#   'treed',
#   'trunk'],
#  41539: ['alienlike',
#   'appear',
#   'appearance',
#   'art',
#   'art_gallery',
#   'atmosphere',
#   'come',
#   'creature',
#   'creatures',
#   'display',
#   'displayed',
#   'eerie',
#   'election',
#   'elections',
#   'encourage',
#   'encouraging',
#   'fill',
#   'filled',
#   'floor',
#   'floors',
#   'gallery',
#   'give',
#   'giving',
#   'humanlike',
#   'illegal',
#   'illegal_immigrant',
#   'illegal_immigrants',
#   'image',
#   'immigrant',
#   'immigrants',
#   'impression',
#   'influence',
#   'large',
#   'large_room',
#   'life',
#   'like',
#   'live',
#   'mannequin',
#   'mean',
#   'mean_like',
#   'moment',
#   'museum',
#   'mysterious',
#   'overall',
#   'room',
#   'sculpture',
#   'sculptures',
#   'set',
#   'setting',
#   'various',
#   'vote',
#   'wooden',
#   'wooden_floor'],
#  37928: ['anaconda',
#   'like',
#   'look',
#   'look_like',
#   'looks',
#   'looks_like',
#   'mouth',
#   'mouth_open',
#   'open',
#   'show',
#   'showing',
#   'snake',
#   'snakes',
#   'snakes_mouth',
#   'teeth',
#   'tongue',
#   'tooth',
#   'vagina'],
#  5162: ['bitch',
#   'bomb',
#   'camera',
#   'glass',
#   'glasses',
#   'go',
#   'man',
#   'muslim',
#   'ol',
#   'old',
#   'old_man',
#   'pussy',
#   'smile',
#   'smiling',
#   'sweater',
#   'wear',
#   'wear_glasses',
#   'wearing',
#   'went'],
#  70698: ['background',
#   'chance',
#   'chest',
#   'neck',
#   'orange',
#   'phone',
#   'steal',
#   'stolen',
#   'tattoo',
#   'tattooed',
#   'tattoos',
#   'woman'],
#  ...}

# %%
uniqueAbsents = set()

for obj in tqdm(allLines):
    # make copy
    id = obj['id']
    graph = obj['graph']

    nodes = graph['nodeDataArray']
    nodesPresent = set()
    # verify that all nodes are present
    for node in nodes:
        nodesPresent.add(node['key'])

    for key in id2Concepts[id]:
        if key not in nodesPresent:
            uniqueAbsents.add(key)
            # print("Node not present")
            # print(key)
            # print(id)

uniqueAbsents
# Out:
# 100%|██████████| 12126/12126 [00:06<00:00, 1820.56it/s]
# {'object', 'people', 'person', 'take', 'uk'}

# %%
allLines[0]['graph'].keys()
# Out:
# dict_keys(['class', 'nodeDataArray', 'linkDataArray', 'contextEmbed'])

# %%
# make new file keeping only top k nodes

lengths = []
edgeLengths = []
for obj in tqdm(allLines):
    # make copy
    id = obj['id']
    graph = obj['graph']

    nodes = graph['nodeDataArray']
    # print(len(nodes))
    # nodes = sorted(nodes, key=lambda x: x['score'], reverse=True)
    # keep all relation nodes
    # relNodes = [node for node in nodes if 'color' not in node or node['color'] == 'yellow']
    # objNodes = [node for node in nodes if 'color' in node and node['color'] != 'yellow']
    # objNodes = sorted(objNodes, key=lambda x: x['score'], reverse=True)
    nodes = sorted(nodes, key=lambda x: x['score'], reverse=True)
    nodesFiltered = nodes[:k]
    # check if any compulsory node is after k and add it
    for i in range(k, len(nodes)):
        if nodes[i]['key'] in id2Concepts[id] or nodes[i]['key'] == 'QAcontext':
            nodesFiltered.append(nodes[i])
    # print(len(objNodes), len(relNodes))
    # nodes = relNodes + objNodes
    # print(len(nodes))

    # assert that all are unique
    # nodesSet = set()
    # for node in nodesFiltered:
    #     if node['key'] in nodesSet:
    #         print(node)
    #     nodesSet.add(node['key'])
    lengths.append(len(nodesFiltered))


    

    # linkDataArray.append({"from": source, "to": target, "relation": relation})
    
    # also update the links
    nodeKeys = set()
    for node in nodesFiltered:
        nodeKeys.add(node['key'])
    links = graph['linkDataArray']
    newLinks = []
    for link in links:
        if (link['from'] in nodeKeys and link['to'] in nodeKeys):
            newLinks.append(link)

    # connect QAcontext to all compulsory nodes
    assert 'QAcontext' in nodeKeys
    for key in id2Concepts[id]:
        if key in nodeKeys:
            newLinks.append({"from": "QAcontext", "to": key, "relation": "QAcontextRel"})
    graph['nodeDataArray'] = nodesFiltered
    # add to edgeLengths
    edgeLengths.append(len(newLinks))
    graph['linkDataArray'] = newLinks
    # remove contextEmbed from graph
    if 'contextEmbed' in graph:
        del graph['contextEmbed']

plt.hist(lengths, bins=100)
plt.show()

plt.hist(edgeLengths, bins=100)
plt.show()
# Out:
# 100%|██████████| 12126/12126 [01:45<00:00, 115.32it/s]

# %%
allLines[0]['graph']['nodeDataArray']
# Out:
# [{'key': 'QAcontext', 'score': 0.0},
#  {'key': 'come_out', 'color': '#ec8c69', 'score': -0.21925179660320282},
#  {'key': 'go_away', 'color': '#ec8c69', 'score': -0.22167889773845673},
#  {'key': 'come_back', 'color': '#ec8c69', 'score': -0.23153534531593323},
#  {'key': 'get_ready', 'color': '#ec8c69', 'score': -0.23281162977218628},
#  {'key': 'be_ready', 'color': '#ec8c69', 'score': -0.23815834522247314},
#  {'key': 'all_right', 'color': '#ec8c69', 'score': -0.2392016053199768},
#  {'key': 'get_out', 'color': '#ec8c69', 'score': -0.24644726514816284},
#  {'key': 'right_now', 'color': '#ec8c69', 'score': -0.24676300585269928},
#  {'key': 'always_be', 'color': '#ec8c69', 'score': -0.24793598055839539},
#  {'key': 'take_over', 'color': '#ec8c69', 'score': -0.25193724036216736},
#  {'key': 'good_to_go', 'color': '#ec8c69', 'score': -0.2523179352283478},
#  {'key': 'go_out', 'color': '#ec8c69', 'score': -0.2575852870941162},
#  {'key': 'all_set', 'color': '#ec8c69', 'score': -0.2646242380142212},
#  {'key': 'stay_still', 'color': '#ec8c69', 'score': -0.27039551734924316},
#  {'key': 'always', 'color': '#ec8c69', 'score': -0.2716641426086426},
#  {'key': 'unenlightenment', 'color': '#ec8c69', 'score': -0.27589261531829834},
#  {'key': 'unenlightened', 'color': '#ec8c69', 'score': -0.2761266827583313},
#  {'key': 'all_done', 'color': '#ec8c69', 'score': -0.2816401422023773},
#  {'key': 'benighted', 'color': '#ec8c69', 'score': -0.28485217690467834},
#  {'key': 'joseph_black', 'color': '#ec8c69', 'score': -0.2888777256011963},
#  {'key': 'captivate', 'color': '#ec8c69', 'score': -0.2909599840641022},
#  {'key': 'ooh_black', 'color': '#ec8c69', 'score': -0.29179948568344116},
#  {'key': 'be_prepared', 'color': '#ec8c69', 'score': -0.29702886939048767},
#  {'key': 'british_isles', 'color': '#ec8c69', 'score': -0.29798105359077454},
#  {'key': 'germany', 'color': '#ec8c69', 'score': -0.30022773146629333},
#  {'key': 'greeks', 'color': '#ec8c69', 'score': -0.3004346191883087},
#  {'key': 'all_in', 'color': '#ec8c69', 'score': -0.3052096962928772},
#  {'key': 'disengage', 'color': '#ec8c69', 'score': -0.3066118657588959},
#  {'key': 'ness', 'color': '#ec8c69', 'score': -0.3103072941303253},
#  {'key': 'may_be', 'color': '#ec8c69', 'score': -0.3130640685558319},
#  {'key': 'get_set', 'color': '#ec8c69', 'score': -0.3160664141178131},
#  {'key': 'sit_down', 'color': '#ec8c69', 'score': -0.3165031671524048},
#  {'key': 'keep_watch', 'color': '#ec8c69', 'score': -0.31913575530052185},
#  {'key': 'ready_and_waiting',
#   'color': '#ec8c69',
#   'score': -0.32264357805252075},
#  {'key': 'fin_de_siecle', 'color': '#ec8c69', 'score': -0.32524052262306213},
#  {'key': 'blackness', 'color': '#ec8c69', 'score': -0.32656580209732056},
#  {'key': 'left_of_center', 'color': '#ec8c69', 'score': -0.3273266553878784},
#  {'key': 'figurative', 'color': '#ec8c69', 'score': -0.3310294449329376},
#  {'key': 'burried_in_ground',
#   'color': '#ec8c69',
#   'score': -0.3339391052722931},
#  {'key': 'brazil', 'color': '#ec8c69', 'score': -0.33434808254241943},
#  {'key': 'clap', 'color': '#ec8c69', 'score': -0.3346559405326843},
#  {'key': 'cinco_de_mayo', 'color': '#ec8c69', 'score': -0.334693044424057},
#  {'key': 'source_code', 'color': '#ec8c69', 'score': -0.3354429304599762},
#  {'key': 'similitude', 'color': '#ec8c69', 'score': -0.33756500482559204},
#  {'key': 'soviet', 'color': '#ec8c69', 'score': -0.3376569151878357},
#  {'key': 'all_around', 'color': '#ec8c69', 'score': -0.3394771218299866},
#  {'key': 'right_on', 'color': '#ec8c69', 'score': -0.34028586745262146},
#  {'key': 'nigh', 'color': '#ec8c69', 'score': -0.34395119547843933},
#  {'key': 'could_happen', 'color': '#ec8c69', 'score': -0.3456394076347351},
#  {'key': 'interrogate', 'color': '#ec8c69', 'score': -0.3458783030509949},
#  {'key': 'looks_like', 'color': '#ec8c69', 'score': -0.3469916582107544},
#  {'key': 'top_bottom', 'color': '#ec8c69', 'score': -0.34850436449050903},
#  {'key': 'sharpen', 'color': '#ec8c69', 'score': -0.3488026261329651},
#  {'key': 'ignominious', 'color': '#ec8c69', 'score': -0.3554636836051941},
#  {'key': 'going_away', 'color': '#ec8c69', 'score': -0.35730692744255066},
#  {'key': 'down_for_count', 'color': '#ec8c69', 'score': -0.35743871331214905},
#  {'key': 'in_addition', 'color': '#ec8c69', 'score': -0.35769063234329224},
#  {'key': 'stand_up', 'color': '#ec8c69', 'score': -0.3592822551727295},
#  {'key': 'be_there', 'color': '#ec8c69', 'score': -0.36006098985671997},
#  {'key': 'ikon', 'color': '#ec8c69', 'score': -0.3663662374019623},
#  {'key': 'aloft', 'color': '#ec8c69', 'score': -0.3715309798717499},
#  {'key': 'hold_up', 'color': '#ec8c69', 'score': -0.373146653175354},
#  {'key': 'situate', 'color': '#ec8c69', 'score': -0.3741334080696106},
#  {'key': 'ellipse', 'color': '#ec8c69', 'score': -0.37472471594810486},
#  {'key': 'sabbatical', 'color': '#ec8c69', 'score': -0.37615567445755005},
#  {'key': 'opposite_of_left', 'color': '#ec8c69', 'score': -0.3763047456741333},
#  {'key': 'give_support_to_another',
#   'color': '#ec8c69',
#   'score': -0.37648406624794006},
#  {'key': 'getting_ready', 'color': '#ec8c69', 'score': -0.37662118673324585},
#  {'key': 'ooh', 'color': '#ec8c69', 'score': -0.3767353594303131},
#  {'key': 'get_up', 'color': '#ec8c69', 'score': -0.37782013416290283},
#  {'key': 'on_you', 'color': '#ec8c69', 'score': -0.3779298663139343},
#  {'key': 'when_done', 'color': '#ec8c69', 'score': -0.3781983554363251},
#  {'key': 'measuring_twelve_inches',
#   'color': '#ec8c69',
#   'score': -0.37922969460487366},
#  {'key': 'gee', 'color': '#ec8c69', 'score': -0.38018688559532166},
#  {'key': 'standing_up', 'color': '#ec8c69', 'score': -0.3814140558242798},
#  {'key': 'saluting', 'color': '#ec8c69', 'score': -0.3840393126010895},
#  {'key': 'everyone', 'color': '#ec8c69', 'score': -0.3845643401145935},
#  {'key': 'affront', 'color': '#ec8c69', 'score': -0.38635334372520447},
#  {'key': 'xi', 'color': '#ec8c69', 'score': -0.3868914842605591},
#  {'key': 'abscence_of_color',
#   'color': '#ec8c69',
#   'score': -0.38713258504867554},
#  {'key': 'clench_into_fist', 'color': '#ec8c69', 'score': -0.3880840241909027},
#  {'key': 'parsimonious', 'color': '#ec8c69', 'score': -0.3921433389186859},
#  {'key': 'attached_to_body', 'color': '#ec8c69', 'score': -0.3927048444747925},
#  {'key': 'human_flesh', 'color': '#ec8c69', 'score': -0.3929738700389862},
#  {'key': 'done_for', 'color': '#ec8c69', 'score': -0.3932282328605652},
#  {'key': 'coffee_beans', 'color': '#ec8c69', 'score': -0.39440566301345825},
#  {'key': 'rouge_et_noir', 'color': '#ec8c69', 'score': -0.39540937542915344},
#  {'key': 'you_can', 'color': '#ec8c69', 'score': -0.39667242765426636},
#  {'key': 'sunderland', 'color': '#ec8c69', 'score': -0.3973035216331482},
#  {'key': 'microscopical', 'color': '#ec8c69', 'score': -0.3973894715309143},
#  {'key': 'graphic_art', 'color': '#ec8c69', 'score': -0.39833101630210876},
#  {'key': 'applying_pressure_to_break',
#   'color': '#ec8c69',
#   'score': -0.4000999927520752},
#  {'key': 'all_encompassing',
#   'color': '#ec8c69',
#   'score': -0.40249699354171753},
#  {'key': 'video_game', 'color': '#ec8c69', 'score': -0.4025053381919861},
#  {'key': 'mensch', 'color': '#ec8c69', 'score': -0.40260449051856995},
#  {'key': 'lefthanded', 'color': '#ec8c69', 'score': -0.40362662076950073},
#  {'key': 'black_market', 'color': '#ec8c69', 'score': -0.40456661581993103},
#  {'key': 'aborigine', 'color': '#ec8c69', 'score': -0.4077226519584656},
#  {'key': 'one_part_of_human_body',
#   'color': '#ec8c69',
#   'score': -0.4077807366847992},
#  {'key': 'gov', 'color': '#ec8c69', 'score': -0.4088447093963623},
#  {'key': 'earthen', 'color': '#ec8c69', 'score': -0.4093098044395447},
#  {'key': 'such_as', 'color': '#ec8c69', 'score': -0.41341179609298706},
#  {'key': 'mary', 'color': '#ec8c69', 'score': -0.41644370555877686},
#  {'key': 'resolute', 'color': '#ec8c69', 'score': -0.4179757237434387},
#  {'key': 'zu', 'color': '#ec8c69', 'score': -0.41880103945732117},
#  {'key': 'body_position', 'color': '#ec8c69', 'score': -0.41919761896133423},
#  {'key': 'big_boy', 'color': '#ec8c69', 'score': -0.41959282755851746},
#  {'key': 'unwavering', 'color': '#ec8c69', 'score': -0.42160046100616455},
#  {'key': 'magic_trick', 'color': '#ec8c69', 'score': -0.4222920835018158},
#  {'key': 'smutty', 'color': '#ec8c69', 'score': -0.42335599660873413},
#  {'key': 'bellow', 'color': '#ec8c69', 'score': -0.4238198399543762},
#  {'key': 'join_in', 'color': '#ec8c69', 'score': -0.423890084028244},
#  {'key': 'indonesia', 'color': '#ec8c69', 'score': -0.4246395528316498},
#  {'key': 'preposition', 'color': '#ec8c69', 'score': -0.42643973231315613},
#  {'key': 'chinese', 'color': '#ec8c69', 'score': -0.42697271704673767},
#  {'key': 'push_people_further_away',
#   'color': '#ec8c69',
#   'score': -0.43000999093055725},
#  {'key': 'out_of_way', 'color': '#ec8c69', 'score': -0.43018263578414917},
#  {'key': 'cimmerian', 'color': '#ec8c69', 'score': -0.4310625493526459},
#  {'key': 'black', 'color': '#ec8c69', 'score': -0.4311715066432953},
#  {'key': 'subgroup', 'color': '#ec8c69', 'score': -0.4348467290401459},
#  {'key': 'homo', 'color': '#ec8c69', 'score': -0.43571093678474426},
#  {'key': 'being_alive', 'color': '#ec8c69', 'score': -0.4369663894176483},
#  {'key': 'opportune', 'color': '#ec8c69', 'score': -0.4377288818359375},
#  {'key': 'luminous_intensity',
#   'color': '#ec8c69',
#   'score': -0.4388276934623718},
#  {'key': 'testifies', 'color': '#ec8c69', 'score': -0.4394227862358093},
#  {'key': 'greater_than_one', 'color': '#ec8c69', 'score': -0.4401398003101349},
#  {'key': 'lengthen', 'color': '#ec8c69', 'score': -0.4415895640850067},
#  {'key': 'visual_phenomenon',
#   'color': '#ec8c69',
#   'score': -0.44284069538116455},
#  {'key': 'run_aground', 'color': '#ec8c69', 'score': -0.443046510219574},
#  {'key': 'cut_down', 'color': '#ec8c69', 'score': -0.4439844787120819},
#  {'key': 'dextrous', 'color': '#ec8c69', 'score': -0.4444613754749298},
#  {'key': 'erode', 'color': '#ec8c69', 'score': -0.445510596036911},
#  {'key': 'june', 'color': '#ec8c69', 'score': -0.44604599475860596},
#  {'key': 'dead', 'color': '#ec8c69', 'score': -0.44611430168151855},
#  {'key': 'mostly_dirt', 'color': '#ec8c69', 'score': -0.446634978055954},
#  {'key': 'dandy', 'color': '#ec8c69', 'score': -0.4474296569824219},
#  {'key': 'homo_sapiens', 'color': '#ec8c69', 'score': -0.4482455849647522},
#  {'key': 'calamitous', 'color': '#ec8c69', 'score': -0.44940319657325745},
#  {'key': 'seduce', 'color': '#ec8c69', 'score': -0.4502483308315277},
#  {'key': 'normal_people', 'color': '#ec8c69', 'score': -0.45139655470848083},
#  {'key': 'cemetary', 'color': '#ec8c69', 'score': -0.45181146264076233},
#  {'key': 'please', 'color': '#ec8c69', 'score': -0.4519810974597931},
#  {'key': 'main_course', 'color': '#ec8c69', 'score': -0.4534345865249634},
#  {'key': 'here', 'color': '#ec8c69', 'score': -0.4546588659286499},
#  {'key': 'bib', 'color': '#ec8c69', 'score': -0.45603030920028687},
#  {'key': 'olympic_event', 'color': '#ec8c69', 'score': -0.4570414125919342},
#  {'key': 'bryophyte', 'color': '#ec8c69', 'score': -0.4578157067298889},
#  {'key': 'now', 'color': '#ec8c69', 'score': -0.45901286602020264},
#  {'key': 'finish_up', 'color': '#ec8c69', 'score': -0.4609757661819458},
#  {'key': 'spread_eagle', 'color': '#ec8c69', 'score': -0.4615781903266907},
#  {'key': 'closeness', 'color': '#ec8c69', 'score': -0.46221858263015747},
#  {'key': 'measurement_equal_to_twelve_inches',
#   'color': '#ec8c69',
#   'score': -0.4623318314552307},
#  {'key': 'darken', 'color': '#ec8c69', 'score': -0.46341243386268616},
#  {'key': 'dextral', 'color': '#ec8c69', 'score': -0.4641764461994171},
#  {'key': 'iniquity', 'color': '#ec8c69', 'score': -0.464572548866272},
#  {'key': 'overall', 'color': '#ec8c69', 'score': -0.4646630883216858},
#  {'key': 'all_together', 'color': '#ec8c69', 'score': -0.46551546454429626},
#  {'key': 'effrontery', 'color': '#ec8c69', 'score': -0.4655616879463196},
#  {'key': 'dark_stuff', 'color': '#ec8c69', 'score': -0.46639204025268555},
#  {'key': 'blackcurrant', 'color': '#ec8c69', 'score': -0.46731793880462646},
#  {'key': 'macroscopical', 'color': '#ec8c69', 'score': -0.4686073958873749},
#  {'key': 'image_copy', 'color': '#ec8c69', 'score': -0.4686175584793091},
#  {'key': 'point_of_view', 'color': '#ec8c69', 'score': -0.47030627727508545},
#  {'key': 'snakebite_and_black',
#   'color': '#ec8c69',
#   'score': -0.47105467319488525},
#  {'key': 'could_be', 'color': '#ec8c69', 'score': -0.47128963470458984},
#  {'key': 'bequeath', 'color': '#ec8c69', 'score': -0.4729659855365753},
#  {'key': 'engross', 'color': '#ec8c69', 'score': -0.4729830324649811},
#  {'key': 'user_interface', 'color': '#ec8c69', 'score': -0.4733339250087738},
#  {'key': 'two_questions', 'color': '#ec8c69', 'score': -0.4733622074127197},
#  {'key': 'at_ready', 'color': '#ec8c69', 'score': -0.47375768423080444},
#  {'key': 'solid_earth', 'color': '#ec8c69', 'score': -0.4742618799209595},
#  {'key': 'superimpose', 'color': '#ec8c69', 'score': -0.4743588864803314},
#  {'key': 'or_right', 'color': '#ec8c69', 'score': -0.4752624034881592},
#  {'key': 'terra_firma', 'color': '#ec8c69', 'score': -0.47584229707717896},
#  {'key': 'can_happen', 'color': '#ec8c69', 'score': -0.4819470942020416},
#  {'key': 'really', 'color': '#ec8c69', 'score': -0.4822606146335602},
#  {'key': 'supposition', 'color': '#ec8c69', 'score': -0.48533865809440613},
#  {'key': 'roll_on', 'color': '#ec8c69', 'score': -0.48623454570770264},
#  {'key': 'outermost_part_of_earth',
#   'color': '#ec8c69',
#   'score': -0.48757433891296387},
#  {'key': 'left_right', 'color': '#ec8c69', 'score': -0.4876653850078583},
#  {'key': 'april_june', 'color': '#ec8c69', 'score': -0.48821279406547546},
#  {'key': 'semidark', 'color': '#ec8c69', 'score': -0.4900228977203369},
#  {'key': 'standstill', 'color': '#ec8c69', 'score': -0.4927648901939392},
#  {'key': 'human_parts', 'color': '#ec8c69', 'score': -0.49470755457878113},
#  {'key': 'game_of_no_chance',
#   'color': '#ec8c69',
#   'score': -0.49554601311683655},
#  {'key': 'lacquer', 'color': '#ec8c69', 'score': -0.4960189759731293},
#  {'key': 'knock_over', 'color': '#ec8c69', 'score': -0.49676746129989624},
#  {'key': 'panorama', 'color': '#ec8c69', 'score': -0.49712321162223816},
#  {'key': 'blossom', 'color': '#ec8c69', 'score': -0.49756425619125366},
#  {'key': 'visage', 'color': '#ec8c69', 'score': -0.4978807866573334},
#  {'key': 'draughts', 'color': '#ec8c69', 'score': -0.4981306791305542},
#  {'key': 'ready', 'color': '#ec8c69', 'score': -0.4983540177345276},
#  {'key': 'left_over', 'color': '#ec8c69', 'score': -0.5015034079551697},
#  {'key': 'chess_move', 'color': '#ec8c69', 'score': -0.502105176448822},
#  {'key': 'crepuscular', 'color': '#ec8c69', 'score': -0.5022783875465393},
#  {'key': 'on_top_of', 'color': '#ec8c69', 'score': -0.502458930015564},
#  {'key': 'picturesque', 'color': '#ec8c69', 'score': -0.5031634569168091},
#  {'key': 'line_of_contact', 'color': '#ec8c69', 'score': -0.5048702955245972},
#  {'key': 'habitually', 'color': '#ec8c69', 'score': -0.505649209022522},
#  {'key': 'intense', 'color': '#ec8c69', 'score': -0.5057875514030457},
#  {'key': 'gregorian_calendar_month',
#   'color': '#ec8c69',
#   'score': -0.5067145824432373},
#  {'key': 'firecracker', 'color': '#ec8c69', 'score': -0.5079060196876526},
#  {'key': 'get_by', 'color': '#ec8c69', 'score': -0.5091567039489746},
#  {'key': 'spatial_coordinates',
#   'color': '#ec8c69',
#   'score': -0.5104385614395142},
#  {'key': 'first_order_collection',
#   'color': '#ec8c69',
#   'score': -0.5120785236358643},
#  {'key': 'broadside', 'color': '#ec8c69', 'score': -0.5131826400756836},
#  {'key': 'telescopic', 'color': '#ec8c69', 'score': -0.5132401585578918},
#  {'key': 'unready', 'color': '#ec8c69', 'score': -0.5139950513839722},
#  {'key': 'big_boned', 'color': '#ec8c69', 'score': -0.5145899653434753},
#  {'key': 'getting_there', 'color': '#ec8c69', 'score': -0.5157223343849182},
#  {'key': 'image', 'color': '#ec8c69', 'score': -0.5165320038795471},
#  {'key': 'enclose', 'color': '#ec8c69', 'score': -0.51839679479599},
#  {'key': 'on_edge', 'color': '#ec8c69', 'score': -0.5187132954597473},
#  {'key': 'fisticuffs', 'color': '#ec8c69', 'score': -0.5194080471992493},
#  {'key': 'dextrous_appendage',
#   'color': '#ec8c69',
#   'score': -0.5209434628486633},
#  {'key': 'human_skin', 'color': '#ec8c69', 'score': -0.5210349559783936},
#  {'key': 'pitiful', 'color': '#ec8c69', 'score': -0.5215911865234375},
#  {'key': 'circumpolar', 'color': '#ec8c69', 'score': -0.5226970911026001},
#  {'key': 'part_of_play', 'color': '#ec8c69', 'score': -0.5229166746139526},
#  {'key': 'again', 'color': '#ec8c69', 'score': -0.5245192050933838},
#  {'key': 'china', 'color': '#ec8c69', 'score': -0.5252050161361694},
#  {'key': 'death', 'color': '#ec8c69', 'score': -0.5259768962860107},
#  {'key': 'reaching_out', 'color': '#ec8c69', 'score': -0.5261393189430237},
#  {'key': 'human_anatomy', 'color': '#ec8c69', 'score': -0.5282340049743652},
#  {'key': 'keep_hands_warm', 'color': '#ec8c69', 'score': -0.5288094878196716},
#  {'key': 'male', 'color': '#ec8c69', 'score': -0.5292115211486816},
#  {'key': 'far_left', 'color': '#ec8c69', 'score': -0.5301165580749512},
#  {'key': 'in_advance', 'color': '#ec8c69', 'score': -0.5303868055343628},
#  {'key': 'fattening', 'color': '#ec8c69', 'score': -0.5307000875473022},
#  {'key': 'seems_like', 'color': '#ec8c69', 'score': -0.5307269096374512},
#  {'key': 'female', 'color': '#ec8c69', 'score': -0.5318031311035156},
#  {'key': 'gummy', 'color': '#ec8c69', 'score': -0.5325559377670288},
#  {'key': 'being_prepared', 'color': '#ec8c69', 'score': -0.5338094830513},
#  {'key': 'darkness', 'color': '#ec8c69', 'score': -0.5360312461853027},
#  {'key': 'five_fingered', 'color': '#ec8c69', 'score': -0.5367496609687805},
#  {'key': 'single_men', 'color': '#ec8c69', 'score': -0.5372009873390198},
#  {'key': 'twi', 'color': '#ec8c69', 'score': -0.5375604033470154},
#  {'key': 'forelimb', 'color': '#ec8c69', 'score': -0.5407030582427979},
#  {'key': 'right_field', 'color': '#ec8c69', 'score': -0.5432500243186951},
#  {'key': 'me_alone', 'color': '#ec8c69', 'score': -0.5464213490486145},
#  {'key': 'boxing_glove', 'color': '#ec8c69', 'score': -0.5464853048324585},
#  {'key': 'flesh_and_bones', 'color': '#ec8c69', 'score': -0.54685378074646},
#  {'key': 'absolute_darkness',
#   'color': '#ec8c69',
#   'score': -0.5485118627548218},
#  {'key': 'yam', 'color': '#ec8c69', 'score': -0.5487216114997864},
#  {'key': 'megascopic', 'color': '#ec8c69', 'score': -0.5492567420005798},
#  {'key': 'men', 'color': '#ec8c69', 'score': -0.5499398708343506},
#  {'key': 'terminus', 'color': '#ec8c69', 'score': -0.550021767616272},
#  {'key': 'fattened', 'color': '#ec8c69', 'score': -0.5510772466659546},
#  {'key': 'handshoe', 'color': '#ec8c69', 'score': -0.5513047575950623},
#  {'key': 'all_you', 'color': '#ec8c69', 'score': -0.5525699257850647},
#  {'key': 'description', 'color': '#ec8c69', 'score': -0.5527843236923218},
#  {'key': 'zero', 'color': '#ec8c69', 'score': -0.5528890490531921},
#  {'key': 'fancy_footwork', 'color': '#ec8c69', 'score': -0.553408682346344},
#  {'key': 'suitability', 'color': '#ec8c69', 'score': -0.5547000169754028},
#  {'key': 'unit_of_measurement',
#   'color': '#ec8c69',
#   'score': -0.5569972991943359},
#  {'key': 'before_action', 'color': '#ec8c69', 'score': -0.5576251745223999},
#  {'key': 'invisible', 'color': '#ec8c69', 'score': -0.5581531524658203},
#  {'key': 'panoptical', 'color': '#ec8c69', 'score': -0.5583515167236328},
#  {'key': 'number_five', 'color': '#ec8c69', 'score': -0.5592575073242188},
#  {'key': 'elapse', 'color': '#ec8c69', 'score': -0.559508204460144},
#  {'key': 'blackened', 'color': '#ec8c69', 'score': -0.5614671111106873},
#  {'key': 'on_earth', 'color': '#ec8c69', 'score': -0.5620271563529968},
#  {'key': 'bottom_floor', 'color': '#ec8c69', 'score': -0.562482476234436},
#  {'key': 'you', 'color': '#ec8c69', 'score': -0.5628480911254883},
#  {'key': 'perplexity', 'color': '#ec8c69', 'score': -0.5633589029312134},
#  {'key': 'corporeal', 'color': '#ec8c69', 'score': -0.5639382004737854},
#  {'key': 'whitethorn', 'color': '#ec8c69', 'score': -0.5641987919807434},
#  {'key': 'intensity', 'color': '#ec8c69', 'score': -0.5643525719642639},
#  {'key': 'checkered_line', 'color': '#ec8c69', 'score': -0.5659527778625488},
#  {'key': 'in_order', 'color': '#ec8c69', 'score': -0.5700880885124207},
#  {'key': 'sprinting', 'color': '#ec8c69', 'score': -0.57036954164505},
#  {'key': 'malign', 'color': '#ec8c69', 'score': -0.5709847807884216},
#  {'key': 'continue', 'color': '#ec8c69', 'score': -0.5739286541938782},
#  {'key': 'october', 'color': '#ec8c69', 'score': -0.5740963220596313},
#  {'key': 'mitt', 'color': '#ec8c69', 'score': -0.57514488697052},
#  {'key': 'urinate', 'color': '#ec8c69', 'score': -0.575699508190155},
#  {'key': 'named_after_maia_goddess_of_fertility',
#   'color': '#ec8c69',
#   'score': -0.5762258172035217},
#  {'key': 'corporeal_entity', 'color': '#ec8c69', 'score': -0.5767268538475037},
#  {'key': 'human', 'color': '#ec8c69', 'score': -0.5782487988471985},
#  {'key': 'body_appendage', 'color': '#ec8c69', 'score': -0.5792734622955322},
#  {'key': 'concealment', 'color': '#ec8c69', 'score': -0.5797314643859863},
#  {'key': 'reach_out', 'color': '#ec8c69', 'score': -0.5817283987998962},
#  {'key': 'after_june', 'color': '#ec8c69', 'score': -0.5818932056427002},
#  {'key': 'encasing', 'color': '#ec8c69', 'score': -0.5828601717948914},
#  {'key': 'facing_forward', 'color': '#ec8c69', 'score': -0.5831550359725952},
#  {'key': 'with_fingers', 'color': '#ec8c69', 'score': -0.583935558795929},
#  {'key': 'scion', 'color': '#ec8c69', 'score': -0.5843102931976318},
#  {'key': 'chirality', 'color': '#ec8c69', 'score': -0.5860873460769653},
#  {'key': 'solid_dirt', 'color': '#ec8c69', 'score': -0.588116466999054},
#  {'key': 'ebony', 'color': '#ec8c69', 'score': -0.5885475873947144},
#  {'key': 'pitch_black', 'color': '#ec8c69', 'score': -0.5896387696266174},
#  {'key': 'i', 'color': '#ec8c69', 'score': -0.5924620628356934},
#  {'key': 'perseverance', 'color': '#ec8c69', 'score': -0.5936411619186401},
#  {'key': 'mitten', 'color': '#ec8c69', 'score': -0.5953604578971863},
#  {'key': 'right_left', 'color': '#ec8c69', 'score': -0.5974134802818298},
#  {'key': 'fortify', 'color': '#ec8c69', 'score': -0.6004695892333984},
#  {'key': 'materialize', 'color': '#ec8c69', 'score': -0.600788414478302},
#  {'key': 'on_floor', 'color': '#ec8c69', 'score': -0.6010364890098572},
#  {'key': 'going_now', 'color': '#ec8c69', 'score': -0.601362407207489},
#  {'key': 'umpire', 'color': '#ec8c69', 'score': -0.6014288067817688},
#  {'key': 'ill_omened', 'color': '#ec8c69', 'score': -0.6035494804382324},
#  {'key': 'okay', 'color': '#ec8c69', 'score': -0.6049715280532837},
#  {'key': 'run_out', 'color': '#ec8c69', 'score': -0.6071752309799194},
#  {'key': 'vista', 'color': '#ec8c69', 'score': -0.6074116230010986},
#  {'key': 'serve_somebody_right',
#   'color': '#ec8c69',
#   'score': -0.6075751781463623},
#  {'key': 'body_parts', 'color': '#ec8c69', 'score': -0.6090988516807556},
#  {'key': 'then', 'color': '#ec8c69', 'score': -0.609200119972229},
#  {'key': 'agglomeration', 'color': '#ec8c69', 'score': -0.6108130812644958},
#  {'key': 'gauntlet', 'color': '#ec8c69', 'score': -0.6124567985534668},
#  {'key': 'selimiye', 'color': '#ec8c69', 'score': -0.6124782562255859},
#  {'key': 'blackish', 'color': '#ec8c69', 'score': -0.613592267036438},
#  {'key': 'one_part', 'color': '#ec8c69', 'score': -0.6146032810211182},
#  {'key': 'lengthening', 'color': '#ec8c69', 'score': -0.6149517893791199},
#  {'key': 'weariness', 'color': '#ec8c69', 'score': -0.6156820058822632},
#  {'key': 'foot_massaging', 'color': '#ec8c69', 'score': -0.6175061464309692},
#  {'key': 'meant_to_start_fire',
#   'color': '#ec8c69',
#   'score': -0.6178547143936157},
#  {'key': 'smelly', 'color': '#ec8c69', 'score': -0.6200833916664124},
#  {'key': 'all_humans', 'color': '#ec8c69', 'score': -0.6206102967262268},
#  {'key': 'clapping', 'color': '#ec8c69', 'score': -0.6206525564193726},
#  {'key': 'catarrh', 'color': '#ec8c69', 'score': -0.6211551427841187},
#  {'key': 'might_happen', 'color': '#ec8c69', 'score': -0.6212359070777893},
#  {'key': 'darker_color_than_white',
#   'color': '#ec8c69',
#   'score': -0.6222906708717346},
#  {'key': 'left_handed', 'color': '#ec8c69', 'score': -0.6238410472869873},
#  {'key': 'gallop', 'color': '#ec8c69', 'score': -0.6252192854881287},
#  {'key': 'maori', 'color': '#ec8c69', 'score': -0.6257492899894714},
#  {'key': 'human_organs', 'color': '#ec8c69', 'score': -0.6268886923789978},
#  {'key': 'lift_weights', 'color': '#ec8c69', 'score': -0.6269333958625793},
#  {'key': 'penultimate', 'color': '#ec8c69', 'score': -0.6274898052215576},
#  {'key': 'assemblage', 'color': '#ec8c69', 'score': -0.6295648217201233},
#  {'key': 'façade', 'color': '#ec8c69', 'score': -0.629621684551239},
#  {'key': 'earthen_floor', 'color': '#ec8c69', 'score': -0.6300327777862549},
#  {'key': 'deuce', 'color': '#ec8c69', 'score': -0.6300951242446899},
#  {'key': 'by_itself', 'color': '#ec8c69', 'score': -0.630627453327179},
#  {'key': 'left_hook', 'color': '#ec8c69', 'score': -0.6313270330429077},
#  {'key': 'in_between', 'color': '#ec8c69', 'score': -0.6313397288322449},
#  {'key': 'dark_color', 'color': '#ec8c69', 'score': -0.6331868767738342},
#  {'key': 'april', 'color': '#ec8c69', 'score': -0.633251428604126},
#  {'key': 'tableau', 'color': '#ec8c69', 'score': -0.6342945098876953},
#  {'key': 'show_up', 'color': '#ec8c69', 'score': -0.6343188881874084},
#  {'key': 'human_race', 'color': '#ec8c69', 'score': -0.6350396275520325},
#  {'key': 'defecate', 'color': '#ec8c69', 'score': -0.6388539671897888},
#  {'key': 'accompaniment', 'color': '#ec8c69', 'score': -0.6389179229736328},
#  {'key': 'encasement', 'color': '#ec8c69', 'score': -0.6391124129295349},
#  {'key': 'go_somewhere', 'color': '#ec8c69', 'score': -0.6392284631729126},
#  {'key': 'boxing', 'color': '#ec8c69', 'score': -0.6397596001625061},
#  {'key': 'headless', 'color': '#ec8c69', 'score': -0.6400459408760071},
#  {'key': 'preform_work', 'color': '#ec8c69', 'score': -0.6415373086929321},
#  {'key': 'dark_colour', 'color': '#ec8c69', 'score': -0.6437528133392334},
#  {'key': 'batman', 'color': '#ec8c69', 'score': -0.6451382040977478},
#  {'key': 'tiredness', 'color': '#ec8c69', 'score': -0.6456279754638672},
#  {'key': 'honourable', 'color': '#ec8c69', 'score': -0.6459459066390991},
#  {'key': 'set_up', 'color': '#ec8c69', 'score': -0.6468474268913269},
#  {'key': 'checkers', 'color': '#ec8c69', 'score': -0.64846271276474},
#  {'key': 'prizefighting', 'color': '#ec8c69', 'score': -0.6495184302330017},
#  {'key': 'true', 'color': '#ec8c69', 'score': -0.6501429080963135},
#  {'key': 'corporeal_person', 'color': '#ec8c69', 'score': -0.6515605449676514},
#  {'key': 'deuces', 'color': '#ec8c69', 'score': -0.6523429751396179},
#  {'key': 'synchronous_sports_event',
#   'color': '#ec8c69',
#   'score': -0.6544317007064819},
#  {'key': 'corporal', 'color': '#ec8c69', 'score': -0.6547860503196716},
#  {'key': 'eroding', 'color': '#ec8c69', 'score': -0.6557002663612366},
#  {'key': 'just', 'color': '#ec8c69', 'score': -0.6569563746452332},
#  {'key': 'england', 'color': '#ec8c69', 'score': -0.657311737537384},
#  {'key': 'go', 'color': '#ec8c69', 'score': -0.6602614521980286},
#  {'key': 'hawthorn', 'color': '#ec8c69', 'score': -0.6616876721382141},
#  {'key': 'technical_knockout',
#   'color': '#ec8c69',
#   'score': -0.6618094444274902},
#  {'key': 'close_to', 'color': '#ec8c69', 'score': -0.6624786853790283},
#  {'key': 'manipulator', 'color': '#ec8c69', 'score': -0.6640732288360596},
#  {'key': 'bivalve', 'color': '#ec8c69', 'score': -0.6640955209732056},
#  {'key': 'cadaver', 'color': '#ec8c69', 'score': -0.6678981184959412},
#  {'key': 'juxtapose', 'color': '#ec8c69', 'score': -0.6682940721511841},
#  {'key': 'two_dimensional', 'color': '#ec8c69', 'score': -0.6685046553611755},
#  {'key': 'now_visible', 'color': '#ec8c69', 'score': -0.6694096922874451},
#  {'key': 'ready_to', 'color': '#ec8c69', 'score': -0.6715863943099976},
#  {'key': 'bright_light', 'color': '#ec8c69', 'score': -0.671701967716217},
#  {'key': 'forethought', 'color': '#ec8c69', 'score': -0.6720059514045715},
#  {'key': 'shows_up', 'color': '#ec8c69', 'score': -0.6720387935638428},
#  {'key': 'step_on_ground', 'color': '#ec8c69', 'score': -0.6721908450126648},
#  {'key': 'shooting_bullets', 'color': '#ec8c69', 'score': -0.6727297902107239},
#  {'key': 'mediterranean', 'color': '#ec8c69', 'score': -0.6750005483627319},
#  {'key': 'clockwise', 'color': '#ec8c69', 'score': -0.6766748428344727},
#  {'key': 'lightness', 'color': '#ec8c69', 'score': -0.6776555180549622},
#  {'key': 'hold_another_hand',
#   'color': '#ec8c69',
#   'score': -0.6777199506759644},
#  {'key': 'enjoy', 'color': '#ec8c69', 'score': -0.6787190437316895},
#  {'key': 'weiqi', 'color': '#ec8c69', 'score': -0.6794062852859497},
#  {'key': 'left_field', 'color': '#ec8c69', 'score': -0.6795026063919067},
#  {'key': 'angry', 'color': '#ec8c69', 'score': -0.6815436482429504},
#  {'key': 'human_physiology', 'color': '#ec8c69', 'score': -0.6818937063217163},
#  {'key': 'landscape_painting',
#   'color': '#ec8c69',
#   'score': -0.6837286353111267},
#  {'key': 'achromatic_color', 'color': '#ec8c69', 'score': -0.6840227842330933},
#  {'key': 'isle_of_man', 'color': '#ec8c69', 'score': -0.6847447156906128},
#  {'key': 'lifting_dumbbell', 'color': '#ec8c69', 'score': -0.6852791905403137},
#  {'key': 'utensil', 'color': '#ec8c69', 'score': -0.6857177019119263},
#  {'key': 'tediously', 'color': '#ec8c69', 'score': -0.6878687143325806},
#  {'key': 'decently', 'color': '#ec8c69', 'score': -0.6883984208106995},
#  {'key': 'appendage', 'color': '#ec8c69', 'score': -0.6890166997909546},
#  {'key': 'stop_standing_in', 'color': '#ec8c69', 'score': -0.6921312808990479},
#  {'key': 'time_travel', 'color': '#ec8c69', 'score': -0.6952839493751526},
#  {'key': 'everything', 'color': '#ec8c69', 'score': -0.6957743763923645},
#  {'key': 'chess_piece', 'color': '#ec8c69', 'score': -0.6962542533874512},
#  {'key': 'before_june', 'color': '#ec8c69', 'score': -0.6968684196472168},
#  {'key': 'fulcrum', 'color': '#ec8c69', 'score': -0.6970028877258301},
#  {'key': 'unilluminated', 'color': '#ec8c69', 'score': -0.6970773935317993},
#  {'key': 'sundown', 'color': '#ec8c69', 'score': -0.6973098516464233},
#  {'key': 'sidelong', 'color': '#ec8c69', 'score': -0.6973462700843811},
#  {'key': 'finland', 'color': '#ec8c69', 'score': -0.6979986429214478},
#  {'key': 'body_part', 'color': '#ec8c69', 'score': -0.698960542678833},
#  {'key': 'skin', 'color': '#ec8c69', 'score': -0.700011134147644},
#  {'key': 'stand_here', 'color': '#ec8c69', 'score': -0.7004223465919495},
#  {'key': 'four_fingers', 'color': '#ec8c69', 'score': -0.7007484436035156},
#  {'key': 'red_october', 'color': '#ec8c69', 'score': -0.7013302445411682},
#  {'key': 'gregorian_calendar',
#   'color': '#ec8c69',
#   'score': -0.7016890645027161},
#  {'key': 'human_corpse', 'color': '#ec8c69', 'score': -0.7020345330238342},
#  {'key': 'five_fingers', 'color': '#ec8c69', 'score': -0.7024245858192444},
#  {'key': 'turned_up', 'color': '#ec8c69', 'score': -0.7024520635604858},
#  {'key': 'itself', 'color': '#ec8c69', 'score': -0.7027689218521118},
#  {'key': 'dirt', 'color': '#ec8c69', 'score': -0.7027772665023804},
#  {'key': 'made_up_of_many_organs',
#   'color': '#ec8c69',
#   'score': -0.7035362720489502},
#  {'key': 'sausages', 'color': '#ec8c69', 'score': -0.7047014236450195},
#  {'key': 'grove', 'color': '#ec8c69', 'score': -0.7047955989837646},
#  {'key': 'upper_cut', 'color': '#ec8c69', 'score': -0.7049120664596558},
#  {'key': 'act_one', 'color': '#ec8c69', 'score': -0.7066471576690674},
#  {'key': 'spades', 'color': '#ec8c69', 'score': -0.7084977626800537},
#  {'key': 'gametophyte', 'color': '#ec8c69', 'score': -0.7087509632110596},
#  {'key': 'checkered_flag', 'color': '#ec8c69', 'score': -0.7095382213592529},
#  {'key': 'boxing_matches', 'color': '#ec8c69', 'score': -0.7111920714378357},
#  {'key': 'stinky', 'color': '#ec8c69', 'score': -0.7116596102714539},
#  {'key': 'begin_work', 'color': '#ec8c69', 'score': -0.7120354175567627},
#  {'key': 'or_out', 'color': '#ec8c69', 'score': -0.7129822373390198},
#  {'key': 'powers_that_be', 'color': '#ec8c69', 'score': -0.7132704854011536},
#  {'key': 'home_plate', 'color': '#ec8c69', 'score': -0.7133881449699402},
#  {'key': 'hidden', 'color': '#ec8c69', 'score': -0.7139315009117126},
#  {'key': 'green_light', 'color': '#ec8c69', 'score': -0.7148275375366211},
#  {'key': 'darkening', 'color': '#ec8c69', 'score': -0.7153905630111694},
#  {'key': 'view', 'color': '#ec8c69', 'score': -0.7162056565284729},
#  {'key': 'dramatic_composition',
#   'color': '#ec8c69',
#   'score': -0.7162595987319946},
#  {'key': 'alone', 'color': '#ec8c69', 'score': -0.7165097594261169},
#  {'key': 'all_prepared', 'color': '#ec8c69', 'score': -0.7165475487709045},
#  {'key': 'red_light', 'color': '#ec8c69', 'score': -0.7171382904052734},
#  {'key': 'arm_extension', 'color': '#ec8c69', 'score': -0.7201769351959229},
#  {'key': 'legwork', 'color': '#ec8c69', 'score': -0.7225772142410278},
#  {'key': 'at_night', 'color': '#ec8c69', 'score': -0.722968339920044},
#  {'key': 'elongate', 'color': '#ec8c69', 'score': -0.7231963276863098},
#  {'key': 'with_legs', 'color': '#ec8c69', 'score': -0.7237866520881653},
#  {'key': 'caliginous', 'color': '#ec8c69', 'score': -0.7238113880157471},
#  {'key': 'on_canvas', 'color': '#ec8c69', 'score': -0.7268242239952087},
#  {'key': 'board_game', 'color': '#ec8c69', 'score': -0.7268918752670288},
#  {'key': 'underfoot', 'color': '#ec8c69', 'score': -0.7273069620132446},
#  {'key': 'hamburger_meat', 'color': '#ec8c69', 'score': -0.7273603081703186},
#  {'key': 'phalanges', 'color': '#ec8c69', 'score': -0.728089451789856},
#  {'key': 'make_ready', 'color': '#ec8c69', 'score': -0.7301253080368042},
#  {'key': 'right', 'color': '#ec8c69', 'score': -0.7302420735359192},
#  {'key': 'human_encasement', 'color': '#ec8c69', 'score': -0.7304462790489197},
#  {'key': 'point_in_space', 'color': '#ec8c69', 'score': -0.7312145233154297},
#  {'key': 'fit_tight', 'color': '#ec8c69', 'score': -0.7314598560333252},
#  {'key': 'ethnic_group', 'color': '#ec8c69', 'score': -0.7315947413444519},
#  {'key': 'right_handed', 'color': '#ec8c69', 'score': -0.7324103713035583},
#  {'key': 'has_legs', 'color': '#ec8c69', 'score': -0.732949435710907},
#  {'key': 'hamburger', 'color': '#ec8c69', 'score': -0.7339529395103455},
#  {'key': 'look_like', 'color': '#ec8c69', 'score': -0.7344192862510681},
#  {'key': 'someone_else', 'color': '#ec8c69', 'score': -0.7351190447807312},
#  {'key': 'unboxing', 'color': '#ec8c69', 'score': -0.735494077205658},
#  {'key': 'stop', 'color': '#ec8c69', 'score': -0.7364889979362488},
#  {'key': 'after_one', 'color': '#ec8c69', 'score': -0.7373425364494324},
#  {'key': 'awol', 'color': '#ec8c69', 'score': -0.7374916672706604},
#  {'key': 'straighten', 'color': '#ec8c69', 'score': -0.7380180954933167},
#  {'key': 'negroid', 'color': '#ec8c69', 'score': -0.7389799952507019},
#  {'key': 'armature', 'color': '#ec8c69', 'score': -0.7399982213973999},
#  {'key': 'glowering', 'color': '#ec8c69', 'score': -0.7409271597862244},
#  {'key': 'maintaining_separation_between_bodies',
#   'color': '#ec8c69',
#   'score': -0.7412136793136597},
#  {'key': 'wear_and_tear', 'color': '#ec8c69', 'score': -0.7415077090263367},
#  {'key': 'transition_zone', 'color': '#ec8c69', 'score': -0.7416914105415344},
#  {'key': 'weightlifting', 'color': '#ec8c69', 'score': -0.7419281601905823},
#  {'key': 'naked', 'color': '#ec8c69', 'score': -0.7447724342346191},
#  {'key': 'strong', 'color': '#ec8c69', 'score': -0.7451415061950684},
#  {'key': 'putting_shoes_on', 'color': '#ec8c69', 'score': -0.7491264343261719},
#  {'key': 'cot', 'color': '#ec8c69', 'score': -0.7505863308906555},
#  {'key': 'handbreadth', 'color': '#ec8c69', 'score': -0.7511044144630432},
#  {'key': 'appendages', 'color': '#ec8c69', 'score': -0.7514826655387878},
#  {'key': 'center', 'color': '#ec8c69', 'score': -0.7535439729690552},
#  {'key': 'human_appendage', 'color': '#ec8c69', 'score': -0.7537402510643005},
#  {'key': 'job_description', 'color': '#ec8c69', 'score': -0.7537622451782227},
#  {'key': 'where_placed', 'color': '#ec8c69', 'score': -0.7555200457572937},
#  {'key': 'transpose', 'color': '#ec8c69', 'score': -0.7564378976821899},
#  {'key': 'proscenium', 'color': '#ec8c69', 'score': -0.7564905285835266},
#  {'key': 'mollusc', 'color': '#ec8c69', 'score': -0.7564948797225952},
#  {'key': 'subroutine', 'color': '#ec8c69', 'score': -0.756658136844635},
#  {'key': 'total_darkness', 'color': '#ec8c69', 'score': -0.7567364573478699},
#  {'key': 'become_visible', 'color': '#ec8c69', 'score': -0.7572882175445557},
#  {'key': 'locomotion', 'color': '#ec8c69', 'score': -0.7583799362182617},
#  {'key': 'caption', 'color': '#ec8c69', 'score': -0.7610179781913757},
#  {'key': 'octave', 'color': '#ec8c69', 'score': -0.7616465091705322},
#  {'key': 'flat_surface', 'color': '#ec8c69', 'score': -0.7618151307106018},
#  {'key': 'putting_socks_on', 'color': '#ec8c69', 'score': -0.7618873715400696},
#  {'key': 'man', 'color': '#ec8c69', 'score': -0.7641257643699646},
#  {'key': 'also', 'color': '#ec8c69', 'score': -0.7642686367034912},
#  {'key': 'manliness', 'color': '#ec8c69', 'score': -0.7643380165100098},
#  {'key': 'two_sausages', 'color': '#ec8c69', 'score': -0.7670325636863708},
#  {'key': 'metal', 'color': '#ec8c69', 'score': -0.7687445282936096},
#  {'key': 'centimetre', 'color': '#ec8c69', 'score': -0.7693851590156555},
#  {'key': 'dark', 'color': '#ec8c69', 'score': -0.7695629596710205},
#  {'key': 'milled', 'color': '#ec8c69', 'score': -0.7704839706420898},
#  {'key': 'leather', 'color': '#ec8c69', 'score': -0.7707425355911255},
#  {'key': 'cello', 'color': '#ec8c69', 'score': -0.7709847092628479},
#  {'key': 'kick_ball', 'color': '#ec8c69', 'score': -0.771803081035614},
#  {'key': 'keep_balance', 'color': '#ec8c69', 'score': -0.7725298404693604},
#  {'key': 'subculture', 'color': '#ec8c69', 'score': -0.7726991772651672},
#  {'key': 'adding_power_to_movement',
#   'color': '#ec8c69',
#   'score': -0.7729179263114929},
#  {'key': 'human_mass', 'color': '#ec8c69', 'score': -0.773582398891449},
#  {'key': 'standing_on', 'color': '#ec8c69', 'score': -0.7738406658172607},
#  {'key': 'bellow_head', 'color': '#ec8c69', 'score': -0.7758201956748962},
#  {'key': 'elongated', 'color': '#ec8c69', 'score': -0.7762848734855652},
#  {'key': 'solidity', 'color': '#ec8c69', 'score': -0.7767595648765564},
#  {'key': 'absolutely_dark', 'color': '#ec8c69', 'score': -0.7771133184432983},
#  {'key': 'one_guy', 'color': '#ec8c69', 'score': -0.7771483063697815},
#  {'key': 'become_white', 'color': '#ec8c69', 'score': -0.7773532271385193},
#  {'key': 'african', 'color': '#ec8c69', 'score': -0.7787385582923889},
#  {'key': 'by_hand', 'color': '#ec8c69', 'score': -0.7789847254753113},
#  {'key': 'elongation', 'color': '#ec8c69', 'score': -0.7809287905693054},
#  {'key': 'balance_on_two_feet',
#   'color': '#ec8c69',
#   'score': -0.7823306322097778},
#  {'key': 'leave_out', 'color': '#ec8c69', 'score': -0.7825860381126404},
#  {'key': 'stock', 'color': '#ec8c69', 'score': -0.7836336493492126},
#  {'key': 'rhizome', 'color': '#ec8c69', 'score': -0.7843799591064453},
#  {'key': 'exactly', 'color': '#ec8c69', 'score': -0.7850651144981384},
#  {'key': 'file_system', 'color': '#ec8c69', 'score': -0.7852428555488586},
#  {'key': 'locomotive', 'color': '#ec8c69', 'score': -0.7858509421348572},
#  {'key': 'decompose', 'color': '#ec8c69', 'score': -0.7870397567749023},
#  {'key': 'put_on', 'color': '#ec8c69', 'score': -0.7900571823120117},
#  {'key': 'powerful_strength', 'color': '#ec8c69', 'score': -0.790536642074585},
#  {'key': 'watch', 'color': '#ec8c69', 'score': -0.7925471663475037},
#  {'key': 'bandstand', 'color': '#ec8c69', 'score': -0.7930068373680115},
#  {'key': 'onlooker', 'color': '#ec8c69', 'score': -0.7956571578979492},
#  {'key': 'change_posture', 'color': '#ec8c69', 'score': -0.7957043647766113},
#  {'key': 'stanza', 'color': '#ec8c69', 'score': -0.7972559928894043},
#  {'key': 'dark_grey', 'color': '#ec8c69', 'score': -0.7976825833320618},
#  {'key': 'three_dimensional',
#   'color': '#ec8c69',
#   'score': -0.7977362275123596},
#  {'key': 'two_arms', 'color': '#ec8c69', 'score': -0.7983677387237549},
#  {'key': 'human_extremity', 'color': '#ec8c69', 'score': -0.7994376420974731},
#  {'key': 'starfish', 'color': '#ec8c69', 'score': -0.800275444984436},
#  {'key': 'stand_on', 'color': '#ec8c69', 'score': -0.802219569683075},
#  {'key': 'night_sky', 'color': '#ec8c69', 'score': -0.8022234439849854},
#  {'key': 'light_fire', 'color': '#ec8c69', 'score': -0.8026568293571472},
#  {'key': 'penmanship', 'color': '#ec8c69', 'score': -0.8029965758323669},
#  {'key': 'bottom_leg', 'color': '#ec8c69', 'score': -0.8041970133781433},
#  {'key': 'upper_body', 'color': '#ec8c69', 'score': -0.8048573732376099},
#  {'key': 'testicles', 'color': '#ec8c69', 'score': -0.8071441054344177},
#  {'key': 'all_parts', 'color': '#ec8c69', 'score': -0.8089877367019653},
#  {'key': 'part_of', 'color': '#ec8c69', 'score': -0.8095077872276306},
#  {'key': 'all_fingers', 'color': '#ec8c69', 'score': -0.8099691867828369},
#  {'key': 'vertical', 'color': '#ec8c69', 'score': -0.8109460473060608},
#  {'key': 'race', 'color': '#ec8c69', 'score': -0.8121393918991089},
#  {'key': 'heraldic', 'color': '#ec8c69', 'score': -0.8125119805335999},
#  {'key': 'alumnus', 'color': '#ec8c69', 'score': -0.8136674165725708},
#  {'key': 'cyme', 'color': '#ec8c69', 'score': -0.8162186145782471},
#  {'key': 'light_candle_to_burn',
#   'color': '#ec8c69',
#   'score': -0.819282054901123},
#  {'key': 'whiten', 'color': '#ec8c69', 'score': -0.8207979202270508},
#  {'key': 'somewhere', 'color': '#ec8c69', 'score': -0.8211824297904968},
#  {'key': 'wifes', 'color': '#ec8c69', 'score': -0.8219000697135925},
#  {'key': 'blacken', 'color': '#ec8c69', 'score': -0.8230136632919312},
#  {'key': 'turn_up', 'color': '#ec8c69', 'score': -0.8235040307044983},
#  {'key': 'jogging', 'color': '#ec8c69', 'score': -0.8248687982559204},
#  {'key': 'preparedness', 'color': '#ec8c69', 'score': -0.8251328468322754},
#  {'key': 'playing_cards', 'color': '#ec8c69', 'score': -0.82569420337677},
#  {'key': 'everyone_involved',
#   'color': '#ec8c69',
#   'score': -0.8275783061981201},
#  {'key': 'shower_gel', 'color': '#ec8c69', 'score': -0.8290141820907593},
#  {'key': 'life', 'color': '#ec8c69', 'score': -0.8353545665740967},
#  {'key': 'witness_stand', 'color': '#ec8c69', 'score': -0.8375822901725769},
#  {'key': 'still', 'color': '#ec8c69', 'score': -0.83790522813797},
#  {'key': 'bodywork', 'color': '#ec8c69', 'score': -0.8380197286605835},
#  {'key': 'on_each', 'color': '#ec8c69', 'score': -0.8382212519645691},
#  {'key': 'appendage_body', 'color': '#ec8c69', 'score': -0.83843594789505},
#  {'key': 'low_down', 'color': '#ec8c69', 'score': -0.8397777080535889},
#  {'key': 'interlock', 'color': '#ec8c69', 'score': -0.8411843776702881},
#  {'key': 'top', 'color': '#ec8c69', 'score': -0.8425087332725525},
#  {'key': 'repel', 'color': '#ec8c69', 'score': -0.8438363671302795},
#  {'key': 'shooting_basketball',
#   'color': '#ec8c69',
#   'score': -0.8450517654418945},
#  {'key': 'batsman', 'color': '#ec8c69', 'score': -0.85223388671875},
#  {'key': 'found_in_hospital',
#   'color': '#ec8c69',
#   'score': -0.8529714941978455},
#  {'key': 'valet', 'color': '#ec8c69', 'score': -0.8575249910354614},
#  {'key': 'ten_fingers', 'color': '#ec8c69', 'score': -0.858657717704773},
#  {'key': 'internal_organs', 'color': '#ec8c69', 'score': -0.8588723540306091},
#  {'key': 'sprawly', 'color': '#ec8c69', 'score': -0.8595937490463257},
#  {'key': 'female_people', 'color': '#ec8c69', 'score': -0.8605140447616577},
#  {'key': 'primate', 'color': '#ec8c69', 'score': -0.8608875870704651},
#  {'key': 'on_something', 'color': '#ec8c69', 'score': -0.8620424866676331},
#  {'key': 'invertebrate', 'color': '#ec8c69', 'score': -0.8651111125946045},
#  {'key': 'anyone', 'color': '#ec8c69', 'score': -0.8658711314201355},
#  {'key': 'women', 'color': '#ec8c69', 'score': -0.8705600500106812},
#  {'key': 'pigmentation', 'color': '#ec8c69', 'score': -0.8710695505142212},
#  {'key': 'perhaps', 'color': '#ec8c69', 'score': -0.8714759349822998},
#  {'key': 'follow', 'color': '#ec8c69', 'score': -0.8715088963508606},
#  {'key': 'something_else', 'color': '#ec8c69', 'score': -0.8749937415122986},
#  {'key': 'its_smelly', 'color': '#ec8c69', 'score': -0.8754514455795288},
#  {'key': 'viscosity', 'color': '#ec8c69', 'score': -0.877387523651123},
#  {'key': 'right_wing', 'color': '#ec8c69', 'score': -0.878189206123352},
#  {'key': 'see', 'color': '#ec8c69', 'score': -0.8798160552978516},
#  {'key': 'pendulous', 'color': '#ec8c69', 'score': -0.880265474319458},
#  {'key': 'bottom', 'color': '#ec8c69', 'score': -0.8818546533584595},
#  {'key': 'using_as_shield', 'color': '#ec8c69', 'score': -0.8819983005523682},
#  {'key': 'have_to_hang_onto',
#   'color': '#ec8c69',
#   'score': -0.8827347755432129},
#  {'key': 'before_hand', 'color': '#ec8c69', 'score': -0.8841425776481628},
#  {'key': 'drive_off', 'color': '#ec8c69', 'score': -0.8854016661643982},
#  {'key': 'left_wing', 'color': '#ec8c69', 'score': -0.8882153630256653},
#  {'key': 'run_low', 'color': '#ec8c69', 'score': -0.8926687836647034},
#  {'key': 'buffy_vampire_slayer',
#   'color': '#ec8c69',
#   'score': -0.895187258720398},
#  {'key': 'human_figure', 'color': '#ec8c69', 'score': -0.8952457904815674},
#  {'key': 'physical_strength',
#   'color': '#ec8c69',
#   'score': -0.8964086174964905},
#  {'key': 'wear_shoes', 'color': '#ec8c69', 'score': -0.9002501368522644},
#  {'key': 'good', 'color': '#ec8c69', 'score': -0.9013552069664001},
#  {'key': 'optical_device', 'color': '#ec8c69', 'score': -0.9020270109176636},
#  {'key': 'spectacles', 'color': '#ec8c69', 'score': -0.9043900966644287},
#  {'key': 'die', 'color': '#ec8c69', 'score': -0.9059918522834778},
#  {'key': 'solid_surface', 'color': '#ec8c69', 'score': -0.9062590599060059},
#  {'key': 'two_legs', 'color': '#ec8c69', 'score': -0.9071270823478699},
#  {'key': 'grownup', 'color': '#ec8c69', 'score': -0.9079132676124573},
#  {'key': 'finish_line', 'color': '#ec8c69', 'score': -0.9083638787269592},
#  {'key': 'night', 'color': '#ec8c69', 'score': -0.9085612297058105},
#  {'key': 'full_torso', 'color': '#ec8c69', 'score': -0.9088512659072876},
#  {'key': 'checkered', 'color': '#ec8c69', 'score': -0.9089513421058655},
#  {'key': 'preventing_cars_from_crossing_train_tracks',
#   'color': '#ec8c69',
#   'score': -0.9104751944541931},
#  {'key': 'band_together', 'color': '#ec8c69', 'score': -0.9115189909934998},
#  {'key': 'human_receptacle', 'color': '#ec8c69', 'score': -0.9130410552024841},
#  {'key': 'there', 'color': '#ec8c69', 'score': -0.9155768156051636},
#  {'key': 'absence_of_light', 'color': '#ec8c69', 'score': -0.9159842729568481},
#  {'key': 'siding', 'color': '#ec8c69', 'score': -0.9173523187637329},
#  {'key': 'beneath_us', 'color': '#ec8c69', 'score': -0.9175658822059631},
#  {'key': 'with_toes', 'color': '#ec8c69', 'score': -0.9176241755485535},
#  {'key': 'cross_each_other', 'color': '#ec8c69', 'score': -0.9179496169090271},
#  {'key': 'planet_earth', 'color': '#ec8c69', 'score': -0.9182079434394836},
#  {'key': 'walk_to_work', 'color': '#ec8c69', 'score': -0.9182737469673157},
#  {'key': 'pose', 'color': '#ec8c69', 'score': -0.9201247096061707},
#  {'key': 'shadow', 'color': '#ec8c69', 'score': -0.9224770665168762},
#  {'key': 'match', 'color': '#ec8c69', 'score': -0.9224787950515747},
#  {'key': 'on_hand', 'color': '#ec8c69', 'score': -0.9246469736099243},
#  {'key': 'gage', 'color': '#ec8c69', 'score': -0.9254869818687439},
#  {'key': 'part_of_leg', 'color': '#ec8c69', 'score': -0.9260491132736206},
#  {'key': 'antalya', 'color': '#ec8c69', 'score': -0.9277376532554626},
#  {'key': 'far_from', 'color': '#ec8c69', 'score': -0.9278031587600708},
#  {'key': 'left_hand', 'color': '#ec8c69', 'score': -0.9308125972747803},
#  {'key': 'epicentre', 'color': '#ec8c69', 'score': -0.9308573603630066},
#  {'key': 'at_hand', 'color': '#ec8c69', 'score': -0.9333547353744507},
#  {'key': 'win_over', 'color': '#ec8c69', 'score': -0.9337129592895508},
#  {'key': 'give_over', 'color': '#ec8c69', 'score': -0.9350060224533081},
#  {'key': 'brown_dirt', 'color': '#ec8c69', 'score': -0.9385024905204773},
#  {'key': 'spiralling', 'color': '#ec8c69', 'score': -0.9398638606071472},
#  {'key': 'absence_of_color', 'color': '#ec8c69', 'score': -0.9405413269996643},
#  {'key': 'sky', 'color': '#ec8c69', 'score': -0.9407809376716614},
#  {'key': 'repose', 'color': '#ec8c69', 'score': -0.94168621301651},
#  {'key': 'fire', 'color': '#ec8c69', 'score': -0.9417448043823242},
#  {'key': 'accordion', 'color': '#ec8c69', 'score': -0.942628026008606},
#  {'key': 'fingers_attached', 'color': '#ec8c69', 'score': -0.9433199763298035},
#  {'key': 'being_done', 'color': '#ec8c69', 'score': -0.9436247944831848},
#  {'key': 'absence_of_colour', 'color': '#ec8c69', 'score': -0.946876049041748},
#  {'key': 'picture', 'color': '#ec8c69', 'score': -0.947408139705658},
#  {'key': 'maybe', 'color': '#ec8c69', 'score': -0.948432207107544},
#  {'key': 'dark_brown', 'color': '#ec8c69', 'score': -0.9494509100914001},
#  {'key': 'attract_attention',
#   'color': '#ec8c69',
#   'score': -0.9500887393951416},
#  {'key': 'many_phalanges', 'color': '#ec8c69', 'score': -0.9511367082595825},
#  {'key': 'red', 'color': '#ec8c69', 'score': -0.9538109302520752},
#  {'key': 'ahead_of', 'color': '#ec8c69', 'score': -0.9556024670600891},
#  {'key': 'human_shape', 'color': '#ec8c69', 'score': -0.9558258056640625},
#  {'key': 'vertebrate_foot', 'color': '#ec8c69', 'score': -0.9572919607162476},
#  {'key': 'pair_of_compasses',
#   'color': '#ec8c69',
#   'score': -0.9590862393379211},
#  {'key': 'walk_on', 'color': '#ec8c69', 'score': -0.9594257473945618},
#  {'key': 'sometimes_stinky', 'color': '#ec8c69', 'score': -0.9616587162017822},
#  {'key': 'raptor', 'color': '#ec8c69', 'score': -0.9625127911567688},
#  {'key': 'focus', 'color': '#ec8c69', 'score': -0.9628220796585083},
#  {'key': 'smelly_sometimes', 'color': '#ec8c69', 'score': -0.9685685038566589},
#  {'key': 'square', 'color': '#ec8c69', 'score': -0.9695916771888733},
#  {'key': 'corporeal_part', 'color': '#ec8c69', 'score': -0.9719074964523315},
#  {'key': 'arrow', 'color': '#ec8c69', 'score': -0.9731284379959106},
#  {'key': 'holding_objects', 'color': '#ec8c69', 'score': -0.9733959436416626},
#  {'key': 'hard', 'color': '#ec8c69', 'score': -0.9762855172157288},
#  {'key': 'boy', 'color': '#ec8c69', 'score': -0.9793433547019958},
#  {'key': 'be_visible', 'color': '#ec8c69', 'score': -0.9798877835273743},
#  {'key': 'share', 'color': '#ec8c69', 'score': -0.9800079464912415},
#  {'key': 'single_guy', 'color': '#ec8c69', 'score': -0.9807472229003906},
#  {'key': 'turn_doorknob', 'color': '#ec8c69', 'score': -0.9840920567512512},
#  {'key': 'light', 'color': '#ec8c69', 'score': -0.9850083589553833},
#  {'key': 'power', 'color': '#ec8c69', 'score': -0.9853945374488831},
#  {'key': 'chernozem', 'color': '#ec8c69', 'score': -0.9877544045448303},
#  {'key': 'twos', 'color': '#ec8c69', 'score': -0.9879167675971985},
#  {'key': 'foreground', 'color': '#ec8c69', 'score': -0.989431619644165},
#  {'key': 'spunk', 'color': '#ec8c69', 'score': -0.9912771582603455},
#  {'key': 'great', 'color': '#ec8c69', 'score': -0.9958315491676331},
#  {'key': 'point_out', 'color': '#ec8c69', 'score': -0.9986512660980225},
#  {'key': 'hand_appendage', 'color': '#ec8c69', 'score': -0.99930340051651},
#  {'key': 'posing', 'color': '#ec8c69', 'score': -1.0008914470672607},
#  {'key': 'human_frame', 'color': '#ec8c69', 'score': -1.0020406246185303},
#  {'key': 'deteriorate', 'color': '#ec8c69', 'score': -1.003679633140564},
#  {'key': 'over', 'color': '#ec8c69', 'score': -1.005708932876587},
#  {'key': 'four_limbs', 'color': '#ec8c69', 'score': -1.0088732242584229},
#  {'key': 'fingered', 'color': '#ec8c69', 'score': -1.0089397430419922},
#  {'key': 'left', 'color': '#ec8c69', 'score': -1.0133260488510132},
#  {'key': 'grey', 'color': '#ec8c69', 'score': -1.015287160873413},
#  {'key': 'conic_section', 'color': '#ec8c69', 'score': -1.0187946557998657},
#  {'key': 'has_fingers', 'color': '#ec8c69', 'score': -1.0195436477661133},
#  {'key': 'bendable', 'color': '#ec8c69', 'score': -1.0214096307754517},
#  {'key': 'style', 'color': '#ec8c69', 'score': -1.0279682874679565},
#  {'key': 'skillfully', 'color': '#ec8c69', 'score': -1.0281786918640137},
#  {'key': 'turn_on_light', 'color': '#ec8c69', 'score': -1.0292372703552246},
#  {'key': 'lower_appendages', 'color': '#ec8c69', 'score': -1.031063199043274},
#  {'key': 'extremity', 'color': '#ec8c69', 'score': -1.0317291021347046},
#  {'key': 'on_body', 'color': '#ec8c69', 'score': -1.0321509838104248},
#  {'key': 'pelvis', 'color': '#ec8c69', 'score': -1.0324559211730957},
#  {'key': 'dude', 'color': '#ec8c69', 'score': -1.032780408859253},
#  {'key': 'close', 'color': '#ec8c69', 'score': -1.034383773803711},
#  {'key': 'confine', 'color': '#ec8c69', 'score': -1.0356166362762451},
#  {'key': 'front_appendage', 'color': '#ec8c69', 'score': -1.0369579792022705},
#  {'key': 'promenade', 'color': '#ec8c69', 'score': -1.0376887321472168},
#  {'key': 'brown', 'color': '#ec8c69', 'score': -1.03789222240448},
#  {'key': 'sewing_machine', 'color': '#ec8c69', 'score': -1.038953423500061},
#  {'key': 'ligament', 'color': '#ec8c69', 'score': -1.0391888618469238},
#  {'key': 'devotee', 'color': '#ec8c69', 'score': -1.0401877164840698},
#  {'key': 'green_means', 'color': '#ec8c69', 'score': -1.0411243438720703},
#  {'key': 'five_digits', 'color': '#ec8c69', 'score': -1.0411758422851562},
#  {'key': 'on_mat', 'color': '#ec8c69', 'score': -1.042187213897705},
#  {'key': 'text', 'color': '#ec8c69', 'score': -1.0422523021697998},
#  {'key': 'with_hands', 'color': '#ec8c69', 'score': -1.042363166809082},
#  {'key': 'attached_to', 'color': '#ec8c69', 'score': -1.0432732105255127},
#  {'key': 'rightward', 'color': '#ec8c69', 'score': -1.0441186428070068},
#  {'key': 'standing', 'color': '#ec8c69', 'score': -1.0447195768356323},
#  {'key': 'ready_set', 'color': '#ec8c69', 'score': -1.0447616577148438},
#  {'key': 'inside_shoe', 'color': '#ec8c69', 'score': -1.0452420711517334},
#  {'key': 'entering_into_contract',
#   'color': '#ec8c69',
#   'score': -1.0456122159957886},
#  {'key': 'armchair', 'color': '#ec8c69', 'score': -1.0460082292556763},
#  {'key': 'skin_covered', 'color': '#ec8c69', 'score': -1.0473514795303345},
#  {'key': 'lighting_fire', 'color': '#ec8c69', 'score': -1.0500030517578125},
#  {'key': 'steel', 'color': '#ec8c69', 'score': -1.0504385232925415},
#  {'key': 'put_together', 'color': '#ec8c69', 'score': -1.051578402519226},
#  {'key': 'soundbox', 'color': '#ec8c69', 'score': -1.0530052185058594},
#  {'key': 'human_being', 'color': '#ec8c69', 'score': -1.0536210536956787},
#  {'key': 'human_body', 'color': '#ec8c69', 'score': -1.0574712753295898},
#  {'key': 'showing_up', 'color': '#ec8c69', 'score': -1.0655933618545532},
#  {'key': 'lower_appendage', 'color': '#ec8c69', 'score': -1.0658801794052124},
#  {'key': 'veracious', 'color': '#ec8c69', 'score': -1.0661479234695435},
#  {'key': 'shank', 'color': '#ec8c69', 'score': -1.0692532062530518},
#  {'key': 'two_shoes', 'color': '#ec8c69', 'score': -1.0702577829360962},
#  {'key': 'human_torso', 'color': '#ec8c69', 'score': -1.0712944269180298},
#  {'key': 'torso_appendages', 'color': '#ec8c69', 'score': -1.071804165840149},
#  {'key': 'on_it', 'color': '#ec8c69', 'score': -1.073108434677124},
#  {'key': 'upper_appendage', 'color': '#ec8c69', 'score': -1.076982855796814},
#  {'key': 'mostly_flat', 'color': '#ec8c69', 'score': -1.0779757499694824},
#  {'key': 'corporeal_form', 'color': '#ec8c69', 'score': -1.0811930894851685},
#  {'key': 'twice', 'color': '#ec8c69', 'score': -1.0836870670318604},
#  {'key': 'has_bicep', 'color': '#ec8c69', 'score': -1.0846318006515503},
#  {'key': 'animal_or_body_part',
#   'color': '#ec8c69',
#   'score': -1.0876303911209106},
#  {'key': 'conic', 'color': '#ec8c69', 'score': -1.0877946615219116},
#  {'key': 'murkiness', 'color': '#ec8c69', 'score': -1.0888501405715942},
#  {'key': 'fight', 'color': '#ec8c69', 'score': -1.0893440246582031},
#  {'key': 'background', 'color': '#ec8c69', 'score': -1.2592625617980957},
#  {'key': 'right_hand', 'color': '#ec8c69', 'score': -1.2611727714538574},
#  {'key': 'scene', 'color': '#ec8c69', 'score': -1.264685869216919},
#  {'key': 'ground', 'color': '#ec8c69', 'score': -1.366457462310791},
#  {'key': 'visible', 'color': '#ec8c69', 'score': -1.3712841272354126},
#  {'key': 'stance', 'color': '#ec8c69', 'score': -1.4284805059432983},
#  {'key': 'position', 'color': '#ec8c69', 'score': -1.6824719905853271},
#  {'key': 'viewer', 'color': '#ec8c69', 'score': -1.6968543529510498},
#  {'key': 'body', 'color': '#ec8c69', 'score': -1.8478100299835205},
#  {'key': 'gloves', 'color': '#ec8c69', 'score': -1.8952757120132446},
#  {'key': 'two', 'color': '#ec8c69', 'score': -1.9142247438430786},
#  {'key': 'front', 'color': '#ec8c69', 'score': -2.1632332801818848},
#  {'key': 'glove', 'color': '#ec8c69', 'score': -2.8153862953186035},
#  {'key': 'side', 'color': '#ec8c69', 'score': -2.9986085891723633},
#  {'key': 'stand', 'color': '#ec8c69', 'score': -3.1653084754943848},
#  {'key': 'wear', 'color': '#ec8c69', 'score': -3.321025848388672},
#  {'key': 'finished', 'color': '#ec8c69', 'score': -3.642113447189331},
#  {'key': 'hand', 'color': '#ec8c69', 'score': -4.319436550140381},
#  {'key': 'wearing', 'color': '#ec8c69', 'score': -4.43662691116333},
#  {'key': 'extended', 'color': '#ec8c69', 'score': -4.49899435043335},
#  {'key': 'arm', 'color': '#ec8c69', 'score': -4.577753067016602},
#  {'key': 'foot', 'color': '#ec8c69', 'score': -5.064815998077393},
#  {'key': 'feet', 'color': '#ec8c69', 'score': -5.253410339355469},
#  {'key': 'capture', 'color': '#ec8c69', 'score': -6.914008140563965},
#  {'key': 'prepare', 'color': '#ec8c69', 'score': -7.21861457824707},
#  {'key': 'positioned', 'color': '#ec8c69', 'score': -7.723264694213867},
#  {'key': 'leave', 'color': '#ec8c69', 'score': -8.201606750488281},
#  {'key': 'finish', 'color': '#ec8c69', 'score': -8.3486967086792},
#  {'key': 'appears', 'color': '#ec8c69', 'score': -8.982450485229492},
#  {'key': 'another', 'color': '#ec8c69', 'score': -9.034168243408203},
#  {'key': 'engage', 'color': '#ec8c69', 'score': -9.310014724731445},
#  {'key': 'additionally', 'color': '#ec8c69', 'score': -10.02901840209961},
#  {'key': 'appear', 'color': '#ec8c69', 'score': -10.522656440734863},
#  {'key': 'deserve', 'color': '#ec8c69', 'score': -10.913924217224121},
#  {'key': 'near', 'color': '#ec8c69', 'score': -11.142173767089844},
#  {'key': 'may', 'color': '#ec8c69', 'score': -11.166462898254395},
#  {'key': 'including', 'color': '#ec8c69', 'score': -11.73337459564209},
#  {'key': 'several', 'color': '#ec8c69', 'score': -11.733595848083496},
#  {'key': 'include', 'color': '#ec8c69', 'score': -12.285514831542969},
#  {'key': 'suggest', 'color': '#ec8c69', 'score': -12.333166122436523},
#  {'key': 'towards', 'color': '#ec8c69', 'score': -13.00359058380127},
#  {'key': 'captures', 'color': '#ec8c69', 'score': -13.232303619384766},
#  {'key': 'suggesting', 'color': '#ec8c69', 'score': -13.261232376098633},
#  {'key': 'might', 'color': '#ec8c69', 'score': -13.324591636657715},
#  {'key': 'extend', 'color': '#ec8c69', 'score': -13.352188110351562},
#  {'key': 'mans', 'color': '#ec8c69', 'score': -14.559419631958008},
#  {'key': 'prepares', 'color': '#ec8c69', 'score': -15.492475509643555}]

# %%
newJsonlFile = f'/scratch/rahul.garg/new_target_fixed_h1RelKmgsTop{k}_noEmbed.jsonl'
jsonFile = open(newJsonlFile, 'w')
for line in tqdm(allLines, total=len(allLines), desc='Writing'):
    json.dump(line, jsonFile)
    jsonFile.write('\n')
jsonFile.close()
# Out:
# Writing: 100%|██████████| 12126/12126 [02:34<00:00, 78.53it/s]

# %%
allLines[0]['graph'].keys()
# Out:
# dict_keys(['class', 'nodeDataArray', 'linkDataArray'])
